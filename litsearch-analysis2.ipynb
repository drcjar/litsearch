# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import argparse
import sys

import sqlite3

import numpy as np
import pandas as pd
from sklearn import metrics
import tensorflow as tf

FLAGS = None

MAX_DOCUMENT_LENGTH = 20
EMBEDDING_SIZE = 100
n_words = 0
MAX_LABEL = 30
WORDS_FEATURE = 'words'  # Name of the input words feature.

# %%
def estimator_spec_for_softmax_classification(
    logits, labels, mode):
  """Returns EstimatorSpec instance for softmax classification."""
  predicted_classes = tf.argmax(logits, 1)
  if mode == tf.estimator.ModeKeys.PREDICT:
    return tf.estimator.EstimatorSpec(
        mode=mode,
        predictions={
            'class': predicted_classes,
            'prob': tf.nn.softmax(logits)
        })

  onehot_labels = tf.one_hot(labels, MAX_LABEL, 1, 0)
  loss = tf.losses.softmax_cross_entropy(
      onehot_labels=onehot_labels, logits=logits)
  if mode == tf.estimator.ModeKeys.TRAIN:
    optimizer = tf.train.AdamOptimizer(learning_rate=0.01)
    train_op = optimizer.minimize(loss, global_step=tf.train.get_global_step())
    return tf.estimator.EstimatorSpec(mode, loss=loss, train_op=train_op)

  eval_metric_ops = {
      'accuracy': tf.metrics.accuracy(
          labels=labels, predictions=predicted_classes)
  }
  return tf.estimator.EstimatorSpec(
      mode=mode, loss=loss, eval_metric_ops=eval_metric_ops)

# %%
def bag_of_words_model(features, labels, mode):
  """A bag-of-words model. Note it disregards the word order in the text."""
  bow_column = tf.feature_column.categorical_column_with_identity(
      WORDS_FEATURE, num_buckets=n_words)
  bow_embedding_column = tf.feature_column.embedding_column(
      bow_column, dimension=EMBEDDING_SIZE)
  bow = tf.feature_column.input_layer(
      features,
      feature_columns=[bow_embedding_column])
  logits = tf.layers.dense(bow, MAX_LABEL, activation=None)

  return estimator_spec_for_softmax_classification(
      logits=logits, labels=labels, mode=mode)

# %%
def rnn_model(features, labels, mode):
  """RNN model to predict from sequence of words to a class."""
  # Convert indexes of words into embeddings.
  # This creates embeddings matrix of [n_words, EMBEDDING_SIZE] and then
  # maps word indexes of the sequence into [batch_size, sequence_length,
  # EMBEDDING_SIZE].
  word_vectors = tf.contrib.layers.embed_sequence(
      features[WORDS_FEATURE], vocab_size=n_words, embed_dim=EMBEDDING_SIZE)

  # Split into list of embedding per word, while removing doc length dim.
  # word_list results to be a list of tensors [batch_size, EMBEDDING_SIZE].
  word_list = tf.unstack(word_vectors, axis=1)

  # Create a Gated Recurrent Unit cell with hidden size of EMBEDDING_SIZE.
  cell = tf.contrib.rnn.GRUCell(EMBEDDING_SIZE)

  # Create an unrolled Recurrent Neural Networks to length of
  # MAX_DOCUMENT_LENGTH and passes word_list as inputs for each unit.
  _, encoding = tf.contrib.rnn.static_rnn(cell, word_list, dtype=tf.float32)

  # Given encoding of RNN, take encoding of last step (e.g hidden size of the
  # neural network of last step) and pass it as features for softmax
  # classification over output classes.
  logits = tf.layers.dense(encoding, MAX_LABEL, activation=None)
  return estimator_spec_for_softmax_classification(
      logits=logits, labels=labels, mode=mode)

# %%
def main(unused_argv):
  global n_words
  # Prepare training and testing data
  conn = sqlite3.connect('papers.db')
  test = pd.read_sql_query('SELECT * FROM papers', conn)
  target = pd.read_csv('ipfjes-case-control-studies.csv', usecols=['pmid','title','firstauthor','lastauthor',
                                                             'journal','pubdate','pubtype',
                                                             'abstract', 'keywords', 'rcr', 'citedby', 'cites'])

  x_train = pd.concat([test.head(9), target.head(9)])['abstract']
  y_train = pd.Series([0 for i in range(9)] + [1 for i in range(9)])
  x_test = pd.concat([test, target.tail(5)])['abstract']
  y_test = pd.Series([0 for i in range(len(test))] + [1 for i in range(5)])
  # Process vocabulary
  vocab_processor = tf.contrib.learn.preprocessing.VocabularyProcessor(
      MAX_DOCUMENT_LENGTH)

  x_transform_train = vocab_processor.fit_transform(x_train)
  x_transform_test = vocab_processor.transform(x_test)

  x_train = np.array(list(x_transform_train))
  x_test = np.array(list(x_transform_test))

  n_words = len(vocab_processor.vocabulary_)
  print('Total words: %d' % n_words)

  # Build model
  # Switch between rnn_model and bag_of_words_model to test different models.
  model_fn = rnn_model
  if FLAGS.bow_model:
    # Subtract 1 because VocabularyProcessor outputs a word-id matrix where word
    # ids start from 1 and 0 means 'no word'. But
    # categorical_column_with_identity assumes 0-based count and uses -1 for
    # missing word.
    x_train -= 1
    x_test -= 1
    model_fn = bag_of_words_model
  classifier = tf.estimator.Estimator(model_fn=model_fn)

  # Train.
  train_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={WORDS_FEATURE: x_train},
      y=y_train,
      batch_size=len(x_train),
      num_epochs=None,
      shuffle=True)
  classifier.train(input_fn=train_input_fn, steps=1000)

  # Predict.
  test_input_fn = tf.estimator.inputs.numpy_input_fn(
      x={WORDS_FEATURE: x_test},
      y=y_test,
      num_epochs=1,
      shuffle=False)
  predictions = classifier.predict(input_fn=test_input_fn)
  y_predicted = np.array(list(p['class'] for p in predictions))
  y_predicted = y_predicted.reshape(np.array(y_test).shape)

  # Score with sklearn.
  score = metrics.accuracy_score(y_test, y_predicted)
  print('Accuracy (sklearn): {0:f}'.format(score))

  # Score with tensorflow.
  scores = classifier.evaluate(input_fn=test_input_fn)
  print('Accuracy (tensorflow): {0:f}'.format(scores['accuracy']))
  return y_predicted, score

# %%
if __name__ == '__main__':
  parser = argparse.ArgumentParser()
  parser.add_argument(
      '--test_with_fake_data',
      default=False,
      help='Test the example code with fake data.',
      action='store_true')
  parser.add_argument(
      '--bow_model',
      default=False,
      help='Run with BOW model instead of RNN.',
      action='store_true')
  FLAGS, unparsed = parser.parse_known_args()
  tf.app.run(main=main, argv=[sys.argv[0]] + unparsed)
# Out:
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbj0xavnr
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_tf_random_seed': 1, '_model_dir': '/tmp/tmpbj0xavnr', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_save_checkpoints_secs': 600, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpbj0xavnr/model.ckpt.
# INFO:tensorflow:loss = 3.4121, step = 1
# INFO:tensorflow:global_step/sec: 59.4199
# INFO:tensorflow:loss = 0.000477391, step = 101 (1.684 sec)
# INFO:tensorflow:global_step/sec: 62.7956
# INFO:tensorflow:loss = 0.000199933, step = 201 (1.593 sec)
# INFO:tensorflow:global_step/sec: 65.5795
# INFO:tensorflow:loss = 0.000163876, step = 301 (1.525 sec)
# INFO:tensorflow:global_step/sec: 63.1993
# INFO:tensorflow:loss = 7.1642e-05, step = 401 (1.582 sec)
# INFO:tensorflow:global_step/sec: 61.4125
# INFO:tensorflow:loss = 5.95958e-05, step = 501 (1.628 sec)
# INFO:tensorflow:global_step/sec: 63.6371
# INFO:tensorflow:loss = 5.20332e-05, step = 601 (1.571 sec)
# INFO:tensorflow:global_step/sec: 64.0266
# INFO:tensorflow:loss = 4.09606e-05, step = 701 (1.562 sec)
# INFO:tensorflow:global_step/sec: 65.0681
# INFO:tensorflow:loss = 2.84243e-05, step = 801 (1.537 sec)
# INFO:tensorflow:global_step/sec: 64.5102
# INFO:tensorflow:loss = 2.5517e-05, step = 901 (1.550 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpbj0xavnr/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.1219e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbj0xavnr/model.ckpt-1000
# Accuracy (sklearn): 0.280880
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:53:56
# INFO:tensorflow:Restoring parameters from /tmp/tmpbj0xavnr/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:53:57
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.28088, global_step = 1000, loss = 4.02018
# Accuracy (tensorflow): 0.280880
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: (array([0, 0, 0, ..., 1, 1, 1]), 0.28087954110898661)
# /home/drcjar/.virtualenvs/tensor/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2870: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
for i in range(100):
    y_predicted, score = main(0)
    if score > 0.9: break
# Out:
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp3fb7l6e6
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp3fb7l6e6', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp3fb7l6e6/model.ckpt.
# INFO:tensorflow:loss = 3.41072, step = 1
# INFO:tensorflow:global_step/sec: 52.5894
# INFO:tensorflow:loss = 0.000809001, step = 101 (1.902 sec)
# INFO:tensorflow:global_step/sec: 62.6981
# INFO:tensorflow:loss = 0.000340006, step = 201 (1.595 sec)
# INFO:tensorflow:global_step/sec: 60.2917
# INFO:tensorflow:loss = 0.000179821, step = 301 (1.659 sec)
# INFO:tensorflow:global_step/sec: 62.3484
# INFO:tensorflow:loss = 0.000163363, step = 401 (1.604 sec)
# INFO:tensorflow:global_step/sec: 62.4272
# INFO:tensorflow:loss = 7.98524e-05, step = 501 (1.602 sec)
# INFO:tensorflow:global_step/sec: 62.5701
# INFO:tensorflow:loss = 6.40061e-05, step = 601 (1.598 sec)
# INFO:tensorflow:global_step/sec: 63.3715
# INFO:tensorflow:loss = 4.98344e-05, step = 701 (1.578 sec)
# INFO:tensorflow:global_step/sec: 63.9185
# INFO:tensorflow:loss = 4.81457e-05, step = 801 (1.564 sec)
# INFO:tensorflow:global_step/sec: 64.2634
# INFO:tensorflow:loss = 3.85499e-05, step = 901 (1.556 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp3fb7l6e6/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.46164e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp3fb7l6e6/model.ckpt-1000
# Accuracy (sklearn): 0.777629
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:54:50
# INFO:tensorflow:Restoring parameters from /tmp/tmp3fb7l6e6/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:54:50
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.777629, global_step = 1000, loss = 1.5007
# Accuracy (tensorflow): 0.777629
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdsb7y2sz
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpdsb7y2sz', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpdsb7y2sz/model.ckpt.
# INFO:tensorflow:loss = 3.40137, step = 1
# INFO:tensorflow:global_step/sec: 51.6799
# INFO:tensorflow:loss = 0.000496889, step = 101 (1.936 sec)
# INFO:tensorflow:global_step/sec: 53.0935
# INFO:tensorflow:loss = 0.000213365, step = 201 (1.884 sec)
# INFO:tensorflow:global_step/sec: 54.5065
# INFO:tensorflow:loss = 0.000101083, step = 301 (1.834 sec)
# INFO:tensorflow:global_step/sec: 61.5648
# INFO:tensorflow:loss = 8.39788e-05, step = 401 (1.624 sec)
# INFO:tensorflow:global_step/sec: 63.4891
# INFO:tensorflow:loss = 5.89734e-05, step = 501 (1.575 sec)
# INFO:tensorflow:global_step/sec: 62.7994
# INFO:tensorflow:loss = 5.79536e-05, step = 601 (1.592 sec)
# INFO:tensorflow:global_step/sec: 59.4387
# INFO:tensorflow:loss = 4.09408e-05, step = 701 (1.683 sec)
# INFO:tensorflow:global_step/sec: 59.8187
# INFO:tensorflow:loss = 2.83118e-05, step = 801 (1.671 sec)
# INFO:tensorflow:global_step/sec: 61.3996
# INFO:tensorflow:loss = 2.6325e-05, step = 901 (1.629 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpdsb7y2sz/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.33382e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdsb7y2sz/model.ckpt-1000
# Accuracy (sklearn): 0.380880
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:55:14
# INFO:tensorflow:Restoring parameters from /tmp/tmpdsb7y2sz/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:55:15
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.38088, global_step = 1000, loss = 3.9693
# Accuracy (tensorflow): 0.380880
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmphttbh_6c
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmphttbh_6c', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmphttbh_6c/model.ckpt.
# INFO:tensorflow:loss = 3.4121, step = 1
# INFO:tensorflow:global_step/sec: 49.3745
# INFO:tensorflow:loss = 0.000477391, step = 101 (2.027 sec)
# INFO:tensorflow:global_step/sec: 52.7146
# INFO:tensorflow:loss = 0.000199933, step = 201 (1.897 sec)
# INFO:tensorflow:global_step/sec: 56.4435
# INFO:tensorflow:loss = 0.000163876, step = 301 (1.772 sec)
# INFO:tensorflow:global_step/sec: 51.8821
# INFO:tensorflow:loss = 7.1642e-05, step = 401 (1.927 sec)
# INFO:tensorflow:global_step/sec: 50.5744
# INFO:tensorflow:loss = 5.95958e-05, step = 501 (1.978 sec)
# INFO:tensorflow:global_step/sec: 54.6174
# INFO:tensorflow:loss = 5.20332e-05, step = 601 (1.831 sec)
# INFO:tensorflow:global_step/sec: 55.1981
# INFO:tensorflow:loss = 4.09606e-05, step = 701 (1.812 sec)
# INFO:tensorflow:global_step/sec: 56.169
# INFO:tensorflow:loss = 2.84243e-05, step = 801 (1.780 sec)
# INFO:tensorflow:global_step/sec: 61.8231
# INFO:tensorflow:loss = 2.5517e-05, step = 901 (1.618 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmphttbh_6c/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.1219e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmphttbh_6c/model.ckpt-1000
# Accuracy (sklearn): 0.280880
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:55:40
# INFO:tensorflow:Restoring parameters from /tmp/tmphttbh_6c/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:55:41
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.28088, global_step = 1000, loss = 4.02018
# Accuracy (tensorflow): 0.280880
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpex8ckp2d
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpex8ckp2d', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpex8ckp2d/model.ckpt.
# INFO:tensorflow:loss = 3.40731, step = 1
# INFO:tensorflow:global_step/sec: 34.7433
# INFO:tensorflow:loss = 0.000396721, step = 101 (2.882 sec)
# INFO:tensorflow:global_step/sec: 45.4364
# INFO:tensorflow:loss = 0.000155529, step = 201 (2.198 sec)
# INFO:tensorflow:global_step/sec: 52.8006
# INFO:tensorflow:loss = 8.50522e-05, step = 301 (1.894 sec)
# INFO:tensorflow:global_step/sec: 54.5186
# INFO:tensorflow:loss = 5.80532e-05, step = 401 (1.834 sec)
# INFO:tensorflow:global_step/sec: 60.0908
# INFO:tensorflow:loss = 4.57488e-05, step = 501 (1.664 sec)
# INFO:tensorflow:global_step/sec: 62.397
# INFO:tensorflow:loss = 3.57091e-05, step = 601 (1.603 sec)
# INFO:tensorflow:global_step/sec: 58.8852
# INFO:tensorflow:loss = 2.93648e-05, step = 701 (1.698 sec)
# INFO:tensorflow:global_step/sec: 62.442
# INFO:tensorflow:loss = 2.23912e-05, step = 801 (1.601 sec)
# INFO:tensorflow:global_step/sec: 59.179
# INFO:tensorflow:loss = 1.97024e-05, step = 901 (1.690 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpex8ckp2d/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.48944e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpex8ckp2d/model.ckpt-1000
# Accuracy (sklearn): 0.824665
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:56:08
# INFO:tensorflow:Restoring parameters from /tmp/tmpex8ckp2d/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:56:09
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.824665, global_step = 1000, loss = 1.47343
# Accuracy (tensorflow): 0.824665
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdnbjyye2
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpdnbjyye2', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpdnbjyye2/model.ckpt.
# INFO:tensorflow:loss = 3.40119, step = 1
# INFO:tensorflow:global_step/sec: 36.4521
# INFO:tensorflow:loss = 0.000197119, step = 101 (2.745 sec)
# INFO:tensorflow:global_step/sec: 50.9318
# INFO:tensorflow:loss = 0.000142323, step = 201 (1.963 sec)
# INFO:tensorflow:global_step/sec: 61.1325
# INFO:tensorflow:loss = 8.36345e-05, step = 301 (1.638 sec)
# INFO:tensorflow:global_step/sec: 61.1355
# INFO:tensorflow:loss = 4.85234e-05, step = 401 (1.633 sec)
# INFO:tensorflow:global_step/sec: 59.4449
# INFO:tensorflow:loss = 4.25299e-05, step = 501 (1.683 sec)
# INFO:tensorflow:global_step/sec: 54.1778
# INFO:tensorflow:loss = 3.07554e-05, step = 601 (1.845 sec)
# INFO:tensorflow:global_step/sec: 59.7367
# INFO:tensorflow:loss = 2.97554e-05, step = 701 (1.674 sec)
# INFO:tensorflow:global_step/sec: 46.5353
# INFO:tensorflow:loss = 2.51329e-05, step = 801 (2.149 sec)
# INFO:tensorflow:global_step/sec: 42.7961
# INFO:tensorflow:loss = 1.91528e-05, step = 901 (2.337 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpdnbjyye2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.93448e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdnbjyye2/model.ckpt-1000
# Accuracy (sklearn): 0.415679
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:56:38
# INFO:tensorflow:Restoring parameters from /tmp/tmpdnbjyye2/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:56:39
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.415679, global_step = 1000, loss = 4.85962
# Accuracy (tensorflow): 0.415679
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpvxfpa9cv
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpvxfpa9cv', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpvxfpa9cv/model.ckpt.
# INFO:tensorflow:loss = 3.40369, step = 1
# INFO:tensorflow:global_step/sec: 45.6137
# INFO:tensorflow:loss = 0.000476701, step = 101 (2.193 sec)
# INFO:tensorflow:global_step/sec: 47.7303
# INFO:tensorflow:loss = 0.000191092, step = 201 (2.095 sec)
# INFO:tensorflow:global_step/sec: 52.2696
# INFO:tensorflow:loss = 0.000158875, step = 301 (1.913 sec)
# INFO:tensorflow:global_step/sec: 54.574
# INFO:tensorflow:loss = 8.8773e-05, step = 401 (1.832 sec)
# INFO:tensorflow:global_step/sec: 63.4987
# INFO:tensorflow:loss = 7.75951e-05, step = 501 (1.575 sec)
# INFO:tensorflow:global_step/sec: 61.6603
# INFO:tensorflow:loss = 6.15429e-05, step = 601 (1.622 sec)
# INFO:tensorflow:global_step/sec: 64.8414
# INFO:tensorflow:loss = 3.73117e-05, step = 701 (1.542 sec)
# INFO:tensorflow:global_step/sec: 64.4139
# INFO:tensorflow:loss = 3.82256e-05, step = 801 (1.552 sec)
# INFO:tensorflow:global_step/sec: 59.1194
# INFO:tensorflow:loss = 3.26429e-05, step = 901 (1.691 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpvxfpa9cv/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.95038e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvxfpa9cv/model.ckpt-1000
# Accuracy (sklearn): 0.446080
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:57:04
# INFO:tensorflow:Restoring parameters from /tmp/tmpvxfpa9cv/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:57:05
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.44608, global_step = 1000, loss = 3.08044
# Accuracy (tensorflow): 0.446080
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpdp3cporh
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpdp3cporh', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpdp3cporh/model.ckpt.
# INFO:tensorflow:loss = 3.40903, step = 1
# INFO:tensorflow:global_step/sec: 39.1105
# INFO:tensorflow:loss = 0.000985011, step = 101 (2.558 sec)
# INFO:tensorflow:global_step/sec: 41.467
# INFO:tensorflow:loss = 0.000237212, step = 201 (2.415 sec)
# INFO:tensorflow:global_step/sec: 49.813
# INFO:tensorflow:loss = 0.000225338, step = 301 (2.004 sec)
# INFO:tensorflow:global_step/sec: 48.4825
# INFO:tensorflow:loss = 8.15809e-05, step = 401 (2.063 sec)
# INFO:tensorflow:global_step/sec: 52.2023
# INFO:tensorflow:loss = 8.7971e-05, step = 501 (1.916 sec)
# INFO:tensorflow:global_step/sec: 53.5794
# INFO:tensorflow:loss = 6.41119e-05, step = 601 (1.865 sec)
# INFO:tensorflow:global_step/sec: 59.8881
# INFO:tensorflow:loss = 4.21592e-05, step = 701 (1.673 sec)
# INFO:tensorflow:global_step/sec: 59.2474
# INFO:tensorflow:loss = 3.67222e-05, step = 801 (1.688 sec)
# INFO:tensorflow:global_step/sec: 48.7846
# INFO:tensorflow:loss = 2.90203e-05, step = 901 (2.047 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpdp3cporh/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.92322e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpdp3cporh/model.ckpt-1000
# Accuracy (sklearn): 0.826195
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:57:33
# INFO:tensorflow:Restoring parameters from /tmp/tmpdp3cporh/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:57:34
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.826195, global_step = 1000, loss = 0.69096
# Accuracy (tensorflow): 0.826195
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpehq2fb4w
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpehq2fb4w', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpehq2fb4w/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 48.0753
# INFO:tensorflow:loss = 0.000286728, step = 101 (2.081 sec)
# INFO:tensorflow:global_step/sec: 48.2763
# INFO:tensorflow:loss = 0.000156327, step = 201 (2.072 sec)
# INFO:tensorflow:global_step/sec: 51.2215
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.951 sec)
# INFO:tensorflow:global_step/sec: 59.942
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.668 sec)
# INFO:tensorflow:global_step/sec: 60.5451
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (1.652 sec)
# INFO:tensorflow:global_step/sec: 60.1293
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (1.663 sec)
# INFO:tensorflow:global_step/sec: 62.3786
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (1.603 sec)
# INFO:tensorflow:global_step/sec: 60.8337
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.645 sec)
# INFO:tensorflow:global_step/sec: 59.5414
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.679 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpehq2fb4w/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpehq2fb4w/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:57:59
# INFO:tensorflow:Restoring parameters from /tmp/tmpehq2fb4w/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:58:00
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp3t0bffw7
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp3t0bffw7', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp3t0bffw7/model.ckpt.
# INFO:tensorflow:loss = 3.40137, step = 1
# INFO:tensorflow:global_step/sec: 38.3699
# INFO:tensorflow:loss = 0.000496889, step = 101 (2.610 sec)
# INFO:tensorflow:global_step/sec: 36.2619
# INFO:tensorflow:loss = 0.000213365, step = 201 (2.756 sec)
# INFO:tensorflow:global_step/sec: 46.6979
# INFO:tensorflow:loss = 0.000101083, step = 301 (2.141 sec)
# INFO:tensorflow:global_step/sec: 48.1866
# INFO:tensorflow:loss = 8.39788e-05, step = 401 (2.075 sec)
# INFO:tensorflow:global_step/sec: 45.2371
# INFO:tensorflow:loss = 5.89734e-05, step = 501 (2.210 sec)
# INFO:tensorflow:global_step/sec: 53.5306
# INFO:tensorflow:loss = 5.79536e-05, step = 601 (1.869 sec)
# INFO:tensorflow:global_step/sec: 41.8288
# INFO:tensorflow:loss = 4.09408e-05, step = 701 (2.390 sec)
# INFO:tensorflow:global_step/sec: 44.8848
# INFO:tensorflow:loss = 2.83118e-05, step = 801 (2.227 sec)
# INFO:tensorflow:global_step/sec: 56.6304
# INFO:tensorflow:loss = 2.6325e-05, step = 901 (1.766 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp3t0bffw7/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.33382e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp3t0bffw7/model.ckpt-1000
# Accuracy (sklearn): 0.380880
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:58:28
# INFO:tensorflow:Restoring parameters from /tmp/tmp3t0bffw7/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:58:29
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.38088, global_step = 1000, loss = 3.9693
# Accuracy (tensorflow): 0.380880
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp_elib6ye
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp_elib6ye', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp_elib6ye/model.ckpt.
# INFO:tensorflow:loss = 3.40017, step = 1
# INFO:tensorflow:global_step/sec: 36.79
# INFO:tensorflow:loss = 0.000600678, step = 101 (2.722 sec)
# INFO:tensorflow:global_step/sec: 40.1362
# INFO:tensorflow:loss = 0.000234179, step = 201 (2.488 sec)
# INFO:tensorflow:global_step/sec: 46.689
# INFO:tensorflow:loss = 0.000126444, step = 301 (2.142 sec)
# INFO:tensorflow:global_step/sec: 51.349
# INFO:tensorflow:loss = 8.40251e-05, step = 401 (1.947 sec)
# INFO:tensorflow:global_step/sec: 59.0588
# INFO:tensorflow:loss = 6.49998e-05, step = 501 (1.693 sec)
# INFO:tensorflow:global_step/sec: 59.5576
# INFO:tensorflow:loss = 6.30261e-05, step = 601 (1.680 sec)
# INFO:tensorflow:global_step/sec: 59.9619
# INFO:tensorflow:loss = 4.61857e-05, step = 701 (1.667 sec)
# INFO:tensorflow:global_step/sec: 60.8433
# INFO:tensorflow:loss = 3.24375e-05, step = 801 (1.644 sec)
# INFO:tensorflow:global_step/sec: 57.0457
# INFO:tensorflow:loss = 2.29011e-05, step = 901 (1.753 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp_elib6ye/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.07555e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp_elib6ye/model.ckpt-1000
# Accuracy (sklearn): 0.711663
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:58:57
# INFO:tensorflow:Restoring parameters from /tmp/tmp_elib6ye/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:58:58
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.711663, global_step = 1000, loss = 1.20085
# Accuracy (tensorflow): 0.711663
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp_i0ttq74
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp_i0ttq74', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp_i0ttq74/model.ckpt.
# INFO:tensorflow:loss = 3.41142, step = 1
# INFO:tensorflow:global_step/sec: 41.8488
# INFO:tensorflow:loss = 0.000703157, step = 101 (2.391 sec)
# INFO:tensorflow:global_step/sec: 46.8865
# INFO:tensorflow:loss = 0.000369062, step = 201 (2.134 sec)
# INFO:tensorflow:global_step/sec: 57.5643
# INFO:tensorflow:loss = 0.000192939, step = 301 (1.736 sec)
# INFO:tensorflow:global_step/sec: 59.4356
# INFO:tensorflow:loss = 0.000129909, step = 401 (1.682 sec)
# INFO:tensorflow:global_step/sec: 58.0321
# INFO:tensorflow:loss = 7.24232e-05, step = 501 (1.723 sec)
# INFO:tensorflow:global_step/sec: 58.7284
# INFO:tensorflow:loss = 4.88149e-05, step = 601 (1.703 sec)
# INFO:tensorflow:global_step/sec: 59.0605
# INFO:tensorflow:loss = 4.53844e-05, step = 701 (1.693 sec)
# INFO:tensorflow:global_step/sec: 56.5768
# INFO:tensorflow:loss = 3.47157e-05, step = 801 (1.767 sec)
# INFO:tensorflow:global_step/sec: 57.6923
# INFO:tensorflow:loss = 2.50468e-05, step = 901 (1.733 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp_i0ttq74/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.82985e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp_i0ttq74/model.ckpt-1000
# Accuracy (sklearn): 0.490440
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:59:23
# INFO:tensorflow:Restoring parameters from /tmp/tmp_i0ttq74/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:59:24
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.49044, global_step = 1000, loss = 3.10885
# Accuracy (tensorflow): 0.490440
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpfuts5y4t
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpfuts5y4t', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpfuts5y4t/model.ckpt.
# INFO:tensorflow:loss = 3.40903, step = 1
# INFO:tensorflow:global_step/sec: 46.8433
# INFO:tensorflow:loss = 0.000985011, step = 101 (2.136 sec)
# INFO:tensorflow:global_step/sec: 43.0933
# INFO:tensorflow:loss = 0.000237212, step = 201 (2.321 sec)
# INFO:tensorflow:global_step/sec: 58.3773
# INFO:tensorflow:loss = 0.000225338, step = 301 (1.713 sec)
# INFO:tensorflow:global_step/sec: 59.3126
# INFO:tensorflow:loss = 8.15809e-05, step = 401 (1.686 sec)
# INFO:tensorflow:global_step/sec: 60.0924
# INFO:tensorflow:loss = 8.7971e-05, step = 501 (1.664 sec)
# INFO:tensorflow:global_step/sec: 63.1115
# INFO:tensorflow:loss = 6.41119e-05, step = 601 (1.584 sec)
# INFO:tensorflow:global_step/sec: 56.3088
# INFO:tensorflow:loss = 4.21592e-05, step = 701 (1.776 sec)
# INFO:tensorflow:global_step/sec: 51.6839
# INFO:tensorflow:loss = 3.67222e-05, step = 801 (1.935 sec)
# INFO:tensorflow:global_step/sec: 62.7495
# INFO:tensorflow:loss = 2.90203e-05, step = 901 (1.594 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpfuts5y4t/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.92322e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpfuts5y4t/model.ckpt-1000
# Accuracy (sklearn): 0.826195
# INFO:tensorflow:Starting evaluation at 2017-07-18-22:59:48
# INFO:tensorflow:Restoring parameters from /tmp/tmpfuts5y4t/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-22:59:49
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.826195, global_step = 1000, loss = 0.69096
# Accuracy (tensorflow): 0.826195
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpshuxq929
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpshuxq929', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpshuxq929/model.ckpt.
# INFO:tensorflow:loss = 3.409, step = 1
# INFO:tensorflow:global_step/sec: 51.9291
# INFO:tensorflow:loss = 0.0001813, step = 101 (1.927 sec)
# INFO:tensorflow:global_step/sec: 55.9157
# INFO:tensorflow:loss = 8.53762e-05, step = 201 (1.788 sec)
# INFO:tensorflow:global_step/sec: 55.0123
# INFO:tensorflow:loss = 4.35898e-05, step = 301 (1.818 sec)
# INFO:tensorflow:global_step/sec: 65.0177
# INFO:tensorflow:loss = 4.03514e-05, step = 401 (1.538 sec)
# INFO:tensorflow:global_step/sec: 57.4519
# INFO:tensorflow:loss = 3.00204e-05, step = 501 (1.741 sec)
# INFO:tensorflow:global_step/sec: 64.6471
# INFO:tensorflow:loss = 1.98746e-05, step = 601 (1.547 sec)
# INFO:tensorflow:global_step/sec: 57.9048
# INFO:tensorflow:loss = 1.74839e-05, step = 701 (1.727 sec)
# INFO:tensorflow:global_step/sec: 63.5818
# INFO:tensorflow:loss = 1.22387e-05, step = 801 (1.573 sec)
# INFO:tensorflow:global_step/sec: 59.8972
# INFO:tensorflow:loss = 1.11195e-05, step = 901 (1.670 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpshuxq929/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.50358e-06.
# INFO:tensorflow:Restoring parameters from /tmp/tmpshuxq929/model.ckpt-1000
# Accuracy (sklearn): 0.708795
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:00:12
# INFO:tensorflow:Restoring parameters from /tmp/tmpshuxq929/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:00:13
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.708795, global_step = 1000, loss = 2.32992
# Accuracy (tensorflow): 0.708795
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpf8gbe_ow
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpf8gbe_ow', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpf8gbe_ow/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 42.7711
# INFO:tensorflow:loss = 0.000286728, step = 101 (2.339 sec)
# INFO:tensorflow:global_step/sec: 50.2052
# INFO:tensorflow:loss = 0.000156327, step = 201 (1.992 sec)
# INFO:tensorflow:global_step/sec: 54.2444
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.843 sec)
# INFO:tensorflow:global_step/sec: 61.1317
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.636 sec)
# INFO:tensorflow:global_step/sec: 63.4496
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (1.576 sec)
# INFO:tensorflow:global_step/sec: 62.5676
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (1.598 sec)
# INFO:tensorflow:global_step/sec: 65.043
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (1.538 sec)
# INFO:tensorflow:global_step/sec: 63.7694
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.568 sec)
# INFO:tensorflow:global_step/sec: 53.379
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.873 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpf8gbe_ow/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpf8gbe_ow/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:00:37
# INFO:tensorflow:Restoring parameters from /tmp/tmpf8gbe_ow/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:00:38
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpy3rhp45a
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpy3rhp45a', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpy3rhp45a/model.ckpt.
# INFO:tensorflow:loss = 3.40042, step = 1
# INFO:tensorflow:global_step/sec: 43.6941
# INFO:tensorflow:loss = 0.000446624, step = 101 (2.290 sec)
# INFO:tensorflow:global_step/sec: 52.3603
# INFO:tensorflow:loss = 0.000192016, step = 201 (1.910 sec)
# INFO:tensorflow:global_step/sec: 49.1404
# INFO:tensorflow:loss = 0.000147901, step = 301 (2.035 sec)
# INFO:tensorflow:global_step/sec: 48.7428
# INFO:tensorflow:loss = 7.86679e-05, step = 401 (2.052 sec)
# INFO:tensorflow:global_step/sec: 49.5027
# INFO:tensorflow:loss = 5.7086e-05, step = 501 (2.020 sec)
# INFO:tensorflow:global_step/sec: 49.0901
# INFO:tensorflow:loss = 4.76625e-05, step = 601 (2.037 sec)
# INFO:tensorflow:global_step/sec: 50.8694
# INFO:tensorflow:loss = 3.33713e-05, step = 701 (1.966 sec)
# INFO:tensorflow:global_step/sec: 50.7176
# INFO:tensorflow:loss = 3.12919e-05, step = 801 (1.973 sec)
# INFO:tensorflow:global_step/sec: 47.8264
# INFO:tensorflow:loss = 2.5378e-05, step = 901 (2.090 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpy3rhp45a/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.906e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpy3rhp45a/model.ckpt-1000
# Accuracy (sklearn): 0.742639
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:01:05
# INFO:tensorflow:Restoring parameters from /tmp/tmpy3rhp45a/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:01:06
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.742639, global_step = 1000, loss = 0.933909
# Accuracy (tensorflow): 0.742639
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9onu_k_9
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp9onu_k_9', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp9onu_k_9/model.ckpt.
# INFO:tensorflow:loss = 3.41063, step = 1
# INFO:tensorflow:global_step/sec: 47.3574
# INFO:tensorflow:loss = 0.000448613, step = 101 (2.113 sec)
# INFO:tensorflow:global_step/sec: 46.2759
# INFO:tensorflow:loss = 0.000203233, step = 201 (2.161 sec)
# INFO:tensorflow:global_step/sec: 53.4106
# INFO:tensorflow:loss = 0.000133571, step = 301 (1.872 sec)
# INFO:tensorflow:global_step/sec: 56.8438
# INFO:tensorflow:loss = 8.88062e-05, step = 401 (1.759 sec)
# INFO:tensorflow:global_step/sec: 62.2251
# INFO:tensorflow:loss = 5.71193e-05, step = 501 (1.607 sec)
# INFO:tensorflow:global_step/sec: 64.3811
# INFO:tensorflow:loss = 4.37487e-05, step = 601 (1.553 sec)
# INFO:tensorflow:global_step/sec: 62.3236
# INFO:tensorflow:loss = 3.41065e-05, step = 701 (1.605 sec)
# INFO:tensorflow:global_step/sec: 61.8397
# INFO:tensorflow:loss = 2.7729e-05, step = 801 (1.617 sec)
# INFO:tensorflow:global_step/sec: 63.6151
# INFO:tensorflow:loss = 2.33713e-05, step = 901 (1.572 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp9onu_k_9/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.07687e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9onu_k_9/model.ckpt-1000
# Accuracy (sklearn): 0.390822
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:01:31
# INFO:tensorflow:Restoring parameters from /tmp/tmp9onu_k_9/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:01:32
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.390822, global_step = 1000, loss = 3.71199
# Accuracy (tensorflow): 0.390822
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpfklwuf7e
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpfklwuf7e', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpfklwuf7e/model.ckpt.
# INFO:tensorflow:loss = 3.40123, step = 1
# INFO:tensorflow:global_step/sec: 48.8306
# INFO:tensorflow:loss = 0.000672502, step = 101 (2.049 sec)
# INFO:tensorflow:global_step/sec: 49.8684
# INFO:tensorflow:loss = 0.000228222, step = 201 (2.005 sec)
# INFO:tensorflow:global_step/sec: 62.9048
# INFO:tensorflow:loss = 0.000130517, step = 301 (1.590 sec)
# INFO:tensorflow:global_step/sec: 64.0917
# INFO:tensorflow:loss = 7.25689e-05, step = 401 (1.560 sec)
# INFO:tensorflow:global_step/sec: 64.3894
# INFO:tensorflow:loss = 6.68405e-05, step = 501 (1.553 sec)
# INFO:tensorflow:global_step/sec: 62.9661
# INFO:tensorflow:loss = 5.42254e-05, step = 601 (1.588 sec)
# INFO:tensorflow:global_step/sec: 61.3305
# INFO:tensorflow:loss = 4.07619e-05, step = 701 (1.631 sec)
# INFO:tensorflow:global_step/sec: 61.9635
# INFO:tensorflow:loss = 3.39541e-05, step = 801 (1.614 sec)
# INFO:tensorflow:global_step/sec: 61.7649
# INFO:tensorflow:loss = 2.99806e-05, step = 901 (1.619 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpfklwuf7e/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.05038e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpfklwuf7e/model.ckpt-1000
# Accuracy (sklearn): 0.761377
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:01:56
# INFO:tensorflow:Restoring parameters from /tmp/tmpfklwuf7e/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:01:57
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.761377, global_step = 1000, loss = 1.10748
# Accuracy (tensorflow): 0.761377
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpsobkcmws
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpsobkcmws', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpsobkcmws/model.ckpt.
# INFO:tensorflow:loss = 3.41142, step = 1
# INFO:tensorflow:global_step/sec: 49.2238
# INFO:tensorflow:loss = 0.000703157, step = 101 (2.033 sec)
# INFO:tensorflow:global_step/sec: 52.5148
# INFO:tensorflow:loss = 0.000369062, step = 201 (1.904 sec)
# INFO:tensorflow:global_step/sec: 49.1424
# INFO:tensorflow:loss = 0.000192939, step = 301 (2.035 sec)
# INFO:tensorflow:global_step/sec: 59.3167
# INFO:tensorflow:loss = 0.000129909, step = 401 (1.686 sec)
# INFO:tensorflow:global_step/sec: 54.7471
# INFO:tensorflow:loss = 7.24232e-05, step = 501 (1.827 sec)
# INFO:tensorflow:global_step/sec: 57.4207
# INFO:tensorflow:loss = 4.88149e-05, step = 601 (1.741 sec)
# INFO:tensorflow:global_step/sec: 61.773
# INFO:tensorflow:loss = 4.53844e-05, step = 701 (1.619 sec)
# INFO:tensorflow:global_step/sec: 63.0094
# INFO:tensorflow:loss = 3.47157e-05, step = 801 (1.587 sec)
# INFO:tensorflow:global_step/sec: 64.1041
# INFO:tensorflow:loss = 2.50468e-05, step = 901 (1.560 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpsobkcmws/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.82985e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpsobkcmws/model.ckpt-1000
# Accuracy (sklearn): 0.490440
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:02:20
# INFO:tensorflow:Restoring parameters from /tmp/tmpsobkcmws/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:02:21
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.49044, global_step = 1000, loss = 3.10885
# Accuracy (tensorflow): 0.490440
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp0kfyvro4
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp0kfyvro4', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp0kfyvro4/model.ckpt.
# INFO:tensorflow:loss = 3.40119, step = 1
# INFO:tensorflow:global_step/sec: 50.4817
# INFO:tensorflow:loss = 0.000197119, step = 101 (1.982 sec)
# INFO:tensorflow:global_step/sec: 52.8524
# INFO:tensorflow:loss = 0.000142323, step = 201 (1.892 sec)
# INFO:tensorflow:global_step/sec: 51.6669
# INFO:tensorflow:loss = 8.36345e-05, step = 301 (1.935 sec)
# INFO:tensorflow:global_step/sec: 56.6651
# INFO:tensorflow:loss = 4.85234e-05, step = 401 (1.765 sec)
# INFO:tensorflow:global_step/sec: 62.9618
# INFO:tensorflow:loss = 4.25299e-05, step = 501 (1.588 sec)
# INFO:tensorflow:global_step/sec: 63.4556
# INFO:tensorflow:loss = 3.07554e-05, step = 601 (1.576 sec)
# INFO:tensorflow:global_step/sec: 62.8688
# INFO:tensorflow:loss = 2.97554e-05, step = 701 (1.590 sec)
# INFO:tensorflow:global_step/sec: 63.6847
# INFO:tensorflow:loss = 2.51329e-05, step = 801 (1.570 sec)
# INFO:tensorflow:global_step/sec: 63.5419
# INFO:tensorflow:loss = 1.91528e-05, step = 901 (1.574 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp0kfyvro4/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.93448e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp0kfyvro4/model.ckpt-1000
# Accuracy (sklearn): 0.415679
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:02:44
# INFO:tensorflow:Restoring parameters from /tmp/tmp0kfyvro4/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:02:45
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.415679, global_step = 1000, loss = 4.85962
# Accuracy (tensorflow): 0.415679
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpt8jjvjte
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpt8jjvjte', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpt8jjvjte/model.ckpt.
# INFO:tensorflow:loss = 3.409, step = 1
# INFO:tensorflow:global_step/sec: 49.7598
# INFO:tensorflow:loss = 0.0001813, step = 101 (2.011 sec)
# INFO:tensorflow:global_step/sec: 48.4322
# INFO:tensorflow:loss = 8.53762e-05, step = 201 (2.065 sec)
# INFO:tensorflow:global_step/sec: 51.1865
# INFO:tensorflow:loss = 4.35898e-05, step = 301 (1.954 sec)
# INFO:tensorflow:global_step/sec: 61.6041
# INFO:tensorflow:loss = 4.03514e-05, step = 401 (1.623 sec)
# INFO:tensorflow:global_step/sec: 62.5071
# INFO:tensorflow:loss = 3.00204e-05, step = 501 (1.600 sec)
# INFO:tensorflow:global_step/sec: 58.7614
# INFO:tensorflow:loss = 1.98746e-05, step = 601 (1.701 sec)
# INFO:tensorflow:global_step/sec: 59.8945
# INFO:tensorflow:loss = 1.74839e-05, step = 701 (1.670 sec)
# INFO:tensorflow:global_step/sec: 58.2012
# INFO:tensorflow:loss = 1.22387e-05, step = 801 (1.718 sec)
# INFO:tensorflow:global_step/sec: 57.9538
# INFO:tensorflow:loss = 1.11195e-05, step = 901 (1.725 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpt8jjvjte/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.50358e-06.
# INFO:tensorflow:Restoring parameters from /tmp/tmpt8jjvjte/model.ckpt-1000
# Accuracy (sklearn): 0.708795
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:03:09
# INFO:tensorflow:Restoring parameters from /tmp/tmpt8jjvjte/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:03:10
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.708795, global_step = 1000, loss = 2.32992
# Accuracy (tensorflow): 0.708795
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp_qikblgv
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp_qikblgv', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp_qikblgv/model.ckpt.
# INFO:tensorflow:loss = 3.40675, step = 1
# INFO:tensorflow:global_step/sec: 38.2327
# INFO:tensorflow:loss = 0.000687291, step = 101 (2.620 sec)
# INFO:tensorflow:global_step/sec: 44.4271
# INFO:tensorflow:loss = 0.000359002, step = 201 (2.248 sec)
# INFO:tensorflow:global_step/sec: 62.0422
# INFO:tensorflow:loss = 0.000229375, step = 301 (1.611 sec)
# INFO:tensorflow:global_step/sec: 61.5086
# INFO:tensorflow:loss = 0.000129631, step = 401 (1.626 sec)
# INFO:tensorflow:global_step/sec: 53.3782
# INFO:tensorflow:loss = 9.27066e-05, step = 501 (1.873 sec)
# INFO:tensorflow:global_step/sec: 52.1397
# INFO:tensorflow:loss = 7.15489e-05, step = 601 (1.918 sec)
# INFO:tensorflow:global_step/sec: 48.7533
# INFO:tensorflow:loss = 5.41458e-05, step = 701 (2.051 sec)
# INFO:tensorflow:global_step/sec: 55.2506
# INFO:tensorflow:loss = 5.02453e-05, step = 801 (1.810 sec)
# INFO:tensorflow:global_step/sec: 47.5081
# INFO:tensorflow:loss = 3.74839e-05, step = 901 (2.106 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp_qikblgv/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.32853e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp_qikblgv/model.ckpt-1000
# Accuracy (sklearn): 0.527342
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:03:39
# INFO:tensorflow:Restoring parameters from /tmp/tmp_qikblgv/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:03:40
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.527342, global_step = 1000, loss = 2.14608
# Accuracy (tensorflow): 0.527342
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbc4funpt
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpbc4funpt', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpbc4funpt/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 45.0017
# INFO:tensorflow:loss = 0.000286728, step = 101 (2.223 sec)
# INFO:tensorflow:global_step/sec: 41.2676
# INFO:tensorflow:loss = 0.000156327, step = 201 (2.424 sec)
# INFO:tensorflow:global_step/sec: 51.5423
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.940 sec)
# INFO:tensorflow:global_step/sec: 53.2699
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.877 sec)
# INFO:tensorflow:global_step/sec: 48.4656
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (2.064 sec)
# INFO:tensorflow:global_step/sec: 47.9757
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (2.085 sec)
# INFO:tensorflow:global_step/sec: 44.0671
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (2.271 sec)
# INFO:tensorflow:global_step/sec: 50.1892
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.990 sec)
# INFO:tensorflow:global_step/sec: 50.1034
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.996 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpbc4funpt/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbc4funpt/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:04:09
# INFO:tensorflow:Restoring parameters from /tmp/tmpbc4funpt/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:04:11
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp1_wep4k0
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp1_wep4k0', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp1_wep4k0/model.ckpt.
# INFO:tensorflow:loss = 3.40903, step = 1
# INFO:tensorflow:global_step/sec: 35.2937
# INFO:tensorflow:loss = 0.000985011, step = 101 (2.837 sec)
# INFO:tensorflow:global_step/sec: 44.1637
# INFO:tensorflow:loss = 0.000237212, step = 201 (2.263 sec)
# INFO:tensorflow:global_step/sec: 53.4883
# INFO:tensorflow:loss = 0.000225338, step = 301 (1.869 sec)
# INFO:tensorflow:global_step/sec: 49.207
# INFO:tensorflow:loss = 8.15809e-05, step = 401 (2.033 sec)
# INFO:tensorflow:global_step/sec: 52.2602
# INFO:tensorflow:loss = 8.7971e-05, step = 501 (1.914 sec)
# INFO:tensorflow:global_step/sec: 52.3116
# INFO:tensorflow:loss = 6.41119e-05, step = 601 (1.911 sec)
# INFO:tensorflow:global_step/sec: 53.2313
# INFO:tensorflow:loss = 4.21592e-05, step = 701 (1.878 sec)
# INFO:tensorflow:global_step/sec: 53.4068
# INFO:tensorflow:loss = 3.67222e-05, step = 801 (1.872 sec)
# INFO:tensorflow:global_step/sec: 54.9796
# INFO:tensorflow:loss = 2.90203e-05, step = 901 (1.819 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp1_wep4k0/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.92322e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp1_wep4k0/model.ckpt-1000
# Accuracy (sklearn): 0.826195
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:04:40
# INFO:tensorflow:Restoring parameters from /tmp/tmp1_wep4k0/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:04:41
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.826195, global_step = 1000, loss = 0.69096
# Accuracy (tensorflow): 0.826195
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpwloyhs98
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpwloyhs98', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpwloyhs98/model.ckpt.
# INFO:tensorflow:loss = 3.40731, step = 1
# INFO:tensorflow:global_step/sec: 38.5722
# INFO:tensorflow:loss = 0.000396721, step = 101 (2.594 sec)
# INFO:tensorflow:global_step/sec: 47.6428
# INFO:tensorflow:loss = 0.000155529, step = 201 (2.099 sec)
# INFO:tensorflow:global_step/sec: 56.0071
# INFO:tensorflow:loss = 8.50522e-05, step = 301 (1.785 sec)
# INFO:tensorflow:global_step/sec: 61.7637
# INFO:tensorflow:loss = 5.80532e-05, step = 401 (1.619 sec)
# INFO:tensorflow:global_step/sec: 59.2628
# INFO:tensorflow:loss = 4.57488e-05, step = 501 (1.687 sec)
# INFO:tensorflow:global_step/sec: 60.9744
# INFO:tensorflow:loss = 3.57091e-05, step = 601 (1.640 sec)
# INFO:tensorflow:global_step/sec: 61.1903
# INFO:tensorflow:loss = 2.93648e-05, step = 701 (1.634 sec)
# INFO:tensorflow:global_step/sec: 60.7413
# INFO:tensorflow:loss = 2.23912e-05, step = 801 (1.646 sec)
# ...
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp4s237mcm/model.ckpt.
# INFO:tensorflow:loss = 3.41063, step = 1
# INFO:tensorflow:global_step/sec: 49.8019
# INFO:tensorflow:loss = 0.000448613, step = 101 (2.009 sec)
# INFO:tensorflow:global_step/sec: 56.1841
# INFO:tensorflow:loss = 0.000203233, step = 201 (1.780 sec)
# INFO:tensorflow:global_step/sec: 64.6922
# INFO:tensorflow:loss = 0.000133571, step = 301 (1.546 sec)
# INFO:tensorflow:global_step/sec: 63.9613
# INFO:tensorflow:loss = 8.88062e-05, step = 401 (1.563 sec)
# INFO:tensorflow:global_step/sec: 63.5493
# INFO:tensorflow:loss = 5.71193e-05, step = 501 (1.574 sec)
# INFO:tensorflow:global_step/sec: 64.0726
# INFO:tensorflow:loss = 4.37487e-05, step = 601 (1.561 sec)
# INFO:tensorflow:global_step/sec: 64.4408
# INFO:tensorflow:loss = 3.41065e-05, step = 701 (1.552 sec)
# INFO:tensorflow:global_step/sec: 64.7693
# INFO:tensorflow:loss = 2.7729e-05, step = 801 (1.544 sec)
# INFO:tensorflow:global_step/sec: 64.5369
# INFO:tensorflow:loss = 2.33713e-05, step = 901 (1.550 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp4s237mcm/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.07687e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp4s237mcm/model.ckpt-1000
# Accuracy (sklearn): 0.390822
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:05:54
# INFO:tensorflow:Restoring parameters from /tmp/tmp4s237mcm/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:05:55
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.390822, global_step = 1000, loss = 3.71199
# Accuracy (tensorflow): 0.390822
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9oi7ube2
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp9oi7ube2', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp9oi7ube2/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 50.0445
# INFO:tensorflow:loss = 0.000286728, step = 101 (1.999 sec)
# INFO:tensorflow:global_step/sec: 51.1878
# INFO:tensorflow:loss = 0.000156327, step = 201 (1.954 sec)
# INFO:tensorflow:global_step/sec: 50.72
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.971 sec)
# INFO:tensorflow:global_step/sec: 54.673
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.829 sec)
# INFO:tensorflow:global_step/sec: 50.4026
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (1.984 sec)
# INFO:tensorflow:global_step/sec: 55.0984
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (1.815 sec)
# INFO:tensorflow:global_step/sec: 59.9142
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (1.669 sec)
# INFO:tensorflow:global_step/sec: 55.8786
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.790 sec)
# INFO:tensorflow:global_step/sec: 61.1756
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.635 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp9oi7ube2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp9oi7ube2/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:06:20
# INFO:tensorflow:Restoring parameters from /tmp/tmp9oi7ube2/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:06:20
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp2_gjyhok
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp2_gjyhok', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp2_gjyhok/model.ckpt.
# INFO:tensorflow:loss = 3.40017, step = 1
# INFO:tensorflow:global_step/sec: 48.8015
# INFO:tensorflow:loss = 0.000600678, step = 101 (2.052 sec)
# INFO:tensorflow:global_step/sec: 50.2002
# INFO:tensorflow:loss = 0.000234179, step = 201 (1.991 sec)
# INFO:tensorflow:global_step/sec: 54.9531
# INFO:tensorflow:loss = 0.000126444, step = 301 (1.820 sec)
# INFO:tensorflow:global_step/sec: 61.1915
# INFO:tensorflow:loss = 8.40251e-05, step = 401 (1.634 sec)
# INFO:tensorflow:global_step/sec: 58.8121
# INFO:tensorflow:loss = 6.49998e-05, step = 501 (1.701 sec)
# INFO:tensorflow:global_step/sec: 57.2598
# INFO:tensorflow:loss = 6.30261e-05, step = 601 (1.746 sec)
# INFO:tensorflow:global_step/sec: 62.7146
# INFO:tensorflow:loss = 4.61857e-05, step = 701 (1.594 sec)
# INFO:tensorflow:global_step/sec: 63.9265
# INFO:tensorflow:loss = 3.24375e-05, step = 801 (1.564 sec)
# INFO:tensorflow:global_step/sec: 62.2624
# INFO:tensorflow:loss = 2.29011e-05, step = 901 (1.606 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp2_gjyhok/model.ckpt.
# INFO:tensorflow:Loss for final step: 3.07555e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp2_gjyhok/model.ckpt-1000
# Accuracy (sklearn): 0.711663
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:06:44
# INFO:tensorflow:Restoring parameters from /tmp/tmp2_gjyhok/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:06:45
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.711663, global_step = 1000, loss = 1.20085
# Accuracy (tensorflow): 0.711663
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp7j3r88kh
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp7j3r88kh', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp7j3r88kh/model.ckpt.
# INFO:tensorflow:loss = 3.40119, step = 1
# INFO:tensorflow:global_step/sec: 42.4871
# INFO:tensorflow:loss = 0.000197119, step = 101 (2.355 sec)
# INFO:tensorflow:global_step/sec: 51.0963
# INFO:tensorflow:loss = 0.000142323, step = 201 (1.957 sec)
# INFO:tensorflow:global_step/sec: 57.8088
# INFO:tensorflow:loss = 8.36345e-05, step = 301 (1.730 sec)
# INFO:tensorflow:global_step/sec: 61.5877
# INFO:tensorflow:loss = 4.85234e-05, step = 401 (1.624 sec)
# INFO:tensorflow:global_step/sec: 55.9109
# INFO:tensorflow:loss = 4.25299e-05, step = 501 (1.789 sec)
# INFO:tensorflow:global_step/sec: 58.5364
# INFO:tensorflow:loss = 3.07554e-05, step = 601 (1.708 sec)
# INFO:tensorflow:global_step/sec: 62.7378
# INFO:tensorflow:loss = 2.97554e-05, step = 701 (1.594 sec)
# INFO:tensorflow:global_step/sec: 60.7594
# INFO:tensorflow:loss = 2.51329e-05, step = 801 (1.646 sec)
# INFO:tensorflow:global_step/sec: 59.8647
# INFO:tensorflow:loss = 1.91528e-05, step = 901 (1.670 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp7j3r88kh/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.93448e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp7j3r88kh/model.ckpt-1000
# Accuracy (sklearn): 0.415679
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:07:09
# INFO:tensorflow:Restoring parameters from /tmp/tmp7j3r88kh/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:07:10
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.415679, global_step = 1000, loss = 4.85962
# Accuracy (tensorflow): 0.415679
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpvi0b91gu
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpvi0b91gu', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpvi0b91gu/model.ckpt.
# INFO:tensorflow:loss = 3.409, step = 1
# INFO:tensorflow:global_step/sec: 51.7922
# INFO:tensorflow:loss = 0.0001813, step = 101 (1.932 sec)
# INFO:tensorflow:global_step/sec: 39.1514
# INFO:tensorflow:loss = 8.53762e-05, step = 201 (2.559 sec)
# INFO:tensorflow:global_step/sec: 43.3549
# INFO:tensorflow:loss = 4.35898e-05, step = 301 (2.302 sec)
# INFO:tensorflow:global_step/sec: 50.314
# INFO:tensorflow:loss = 4.03514e-05, step = 401 (1.988 sec)
# INFO:tensorflow:global_step/sec: 58.314
# INFO:tensorflow:loss = 3.00204e-05, step = 501 (1.715 sec)
# INFO:tensorflow:global_step/sec: 58.2393
# INFO:tensorflow:loss = 1.98746e-05, step = 601 (1.717 sec)
# INFO:tensorflow:global_step/sec: 53.8512
# INFO:tensorflow:loss = 1.74839e-05, step = 701 (1.858 sec)
# INFO:tensorflow:global_step/sec: 60.3496
# INFO:tensorflow:loss = 1.22387e-05, step = 801 (1.656 sec)
# INFO:tensorflow:global_step/sec: 59.5994
# INFO:tensorflow:loss = 1.11195e-05, step = 901 (1.678 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpvi0b91gu/model.ckpt.
# INFO:tensorflow:Loss for final step: 9.50358e-06.
# INFO:tensorflow:Restoring parameters from /tmp/tmpvi0b91gu/model.ckpt-1000
# Accuracy (sklearn): 0.708795
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:07:36
# INFO:tensorflow:Restoring parameters from /tmp/tmpvi0b91gu/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:07:37
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.708795, global_step = 1000, loss = 2.32992
# Accuracy (tensorflow): 0.708795
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpbzwxhfp_
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpbzwxhfp_', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpbzwxhfp_/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 39.2184
# INFO:tensorflow:loss = 0.000286728, step = 101 (2.551 sec)
# INFO:tensorflow:global_step/sec: 46.0385
# INFO:tensorflow:loss = 0.000156327, step = 201 (2.172 sec)
# INFO:tensorflow:global_step/sec: 52.0602
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.921 sec)
# INFO:tensorflow:global_step/sec: 60.4123
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.655 sec)
# INFO:tensorflow:global_step/sec: 52.2463
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (1.915 sec)
# INFO:tensorflow:global_step/sec: 55.5524
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (1.799 sec)
# INFO:tensorflow:global_step/sec: 57.2955
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (1.745 sec)
# INFO:tensorflow:global_step/sec: 62.1693
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.610 sec)
# INFO:tensorflow:global_step/sec: 55.3784
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.804 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpbzwxhfp_/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbzwxhfp_/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:08:04
# INFO:tensorflow:Restoring parameters from /tmp/tmpbzwxhfp_/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:08:06
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp8fjh5ji2
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmp8fjh5ji2', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp8fjh5ji2/model.ckpt.
# INFO:tensorflow:loss = 3.4017, step = 1
# INFO:tensorflow:global_step/sec: 47.3296
# INFO:tensorflow:loss = 0.000286728, step = 101 (2.114 sec)
# INFO:tensorflow:global_step/sec: 45.8013
# INFO:tensorflow:loss = 0.000156327, step = 201 (2.183 sec)
# INFO:tensorflow:global_step/sec: 54.3825
# INFO:tensorflow:loss = 9.88579e-05, step = 301 (1.839 sec)
# INFO:tensorflow:global_step/sec: 53.1497
# INFO:tensorflow:loss = 8.61374e-05, step = 401 (1.882 sec)
# INFO:tensorflow:global_step/sec: 50.9979
# INFO:tensorflow:loss = 4.5914e-05, step = 501 (1.961 sec)
# INFO:tensorflow:global_step/sec: 47.8852
# INFO:tensorflow:loss = 3.88547e-05, step = 601 (2.088 sec)
# INFO:tensorflow:global_step/sec: 60.2201
# INFO:tensorflow:loss = 3.24176e-05, step = 701 (1.661 sec)
# INFO:tensorflow:global_step/sec: 58.8035
# INFO:tensorflow:loss = 2.6868e-05, step = 801 (1.700 sec)
# INFO:tensorflow:global_step/sec: 60.3792
# INFO:tensorflow:loss = 2.18746e-05, step = 901 (1.656 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmp8fjh5ji2/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.8113e-05.
# INFO:tensorflow:Restoring parameters from /tmp/tmp8fjh5ji2/model.ckpt-1000
# Accuracy (sklearn): 0.481071
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:08:32
# INFO:tensorflow:Restoring parameters from /tmp/tmp8fjh5ji2/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:08:33
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.481071, global_step = 1000, loss = 2.54313
# Accuracy (tensorflow): 0.481071
# Total words: 1127
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpqo0d5b9j
# INFO:tensorflow:Using config: {'_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_secs': 600, '_model_dir': '/tmp/tmpqo0d5b9j', '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_tf_random_seed': 1, '_session_config': None}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpqo0d5b9j/model.ckpt.
# INFO:tensorflow:loss = 3.40835, step = 1
# INFO:tensorflow:global_step/sec: 48.6364
# INFO:tensorflow:loss = 0.000191976, step = 101 (2.057 sec)
# INFO:tensorflow:global_step/sec: 51.6231
# INFO:tensorflow:loss = 8.9508e-05, step = 201 (1.937 sec)
# INFO:tensorflow:global_step/sec: 54.1544
# INFO:tensorflow:loss = 5.41455e-05, step = 301 (1.846 sec)
# INFO:tensorflow:global_step/sec: 58.2953
# INFO:tensorflow:loss = 3.61859e-05, step = 401 (1.715 sec)
# INFO:tensorflow:global_step/sec: 59.7794
# INFO:tensorflow:loss = 2.157e-05, step = 501 (1.673 sec)
# INFO:tensorflow:global_step/sec: 62.5415
# INFO:tensorflow:loss = 1.62521e-05, step = 601 (1.599 sec)
# INFO:tensorflow:global_step/sec: 63.1958
# INFO:tensorflow:loss = 1.48017e-05, step = 701 (1.582 sec)
# INFO:tensorflow:global_step/sec: 59.4306
# INFO:tensorflow:loss = 1.22122e-05, step = 801 (1.683 sec)
# INFO:tensorflow:global_step/sec: 58.9621
# INFO:tensorflow:loss = 1.21195e-05, step = 901 (1.695 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpqo0d5b9j/model.ckpt.
# INFO:tensorflow:Loss for final step: 7.54327e-06.
# INFO:tensorflow:Restoring parameters from /tmp/tmpqo0d5b9j/model.ckpt-1000
# Accuracy (sklearn): 0.908987
# INFO:tensorflow:Starting evaluation at 2017-07-18-23:08:57
# INFO:tensorflow:Restoring parameters from /tmp/tmpqo0d5b9j/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-07-18-23:08:59
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.908987, global_step = 1000, loss = 0.584568
# Accuracy (tensorflow): 0.908987

# %%
len(y_predicted)
# Out:
# 5230

# %%
conn = sqlite3.connect('papers.db')
test = pd.read_sql_query('SELECT * FROM papers', conn)
len(test)
# Out:
# 5225

# %%
test['pred'] = y_predicted[:5225]

# %%
len(test[test['pred'] == 1])
# Out:
# 474

# %%
test[test['pred'] == 1].to_csv('ipf-rnn-model.csv')

# %%
result = test[test['pred'] == 1].head()

# %%
pd.set_option('max_colwidth',1000)
result[['pmid', 'date', 'author', 'title', 'journal']]
# Out:
#          pmid         date  \
# 39   26724656     2016 Jan
# 53   26359263     2015 Dec
# 58   26415518  2015 Sep 29
# 73   26324805     2015 Sep
# 119  25260757  2014 Nov 01
#
#                                                                                                                                               author  \
# 39                                                                 Nakagawa H, Nagatani Y, Takahashi M, Ogawa E, Tho NV, Ryujin Y, Nagao T, Nakano Y
# 53              Umeda Y, Demura Y, Morikawa M, Anzai M, Kadowaki M, Ameshima S, Tsuchida T, Tsujikawa T, Kiyono Y, Okazawa H, Ishizaki T, Ishizuka T
# 58   Sokai A, Handa T, Tanizawa K, Oga T, Uno K, Tsuruyama T, Kubo T, Ikezoe K, Nakatsuka Y, Tanimura K, Muro S, Hirai T, Nagai S, Chin K, Mishima M
# 73                                                                                                Caminati A, Madotto F, Cesana G, Conti S, Harari S
# 119                                                                                                                      Ley B, Brown KK, Collard HR
#
#                                                                                                                            title  \
# 39   Quantitative CT analysis of honeycombing area in idiopathic pulmonary fibrosis: Correlations with pulmonary function tests.
# 53                                            Prognostic Value of Dual-Time-Point 18F-FDG PET for Idiopathic Pulmonary Fibrosis.
# 58                                             Matrix metalloproteinase-10: a novel biomarker for idiopathic pulmonary fibrosis.
# 73                  Epidemiological studies in idiopathic pulmonary fibrosis: pitfalls in methodologies and data interpretation.
# 119                                                                       Molecular biomarkers in idiopathic pulmonary fibrosis.
#
#                                                                                    journal
# 39                                                           European journal of radiology
# 53         Journal of nuclear medicine : official publication, Society of Nuclear Medicine
# 58                                                                    Respiratory research
# 73   European respiratory review : an official journal of the European Respiratory Society
# 119                 American journal of physiology. Lung cellular and molecular physiology
