# %% [markdown]
# # NetworkX Visualization Powered by Bokeh
#
# <br>
# ### EuroPython 2016 (2016-07-22)
#
# ###### Björn Meier

# %% [markdown]
# ### Original Objectives:
# * exploring networks for patterns based on properties like node centrality or clustering
# * visualization in a browser
#
# <br>

# %% [markdown]
# ### Original Solution:
# * generate networks and properties
# * RESTful Flask app to provide data
# * D3.js app for browser visualization

# %% [markdown]
# ## Can we solve this easier?

# %% [markdown]
# ### NetworkX + Bokeh
#
# * define the visualization in pure python
# * interact with your network
#     * change views or change showed properties
#     * manipulate the network and get an updated plot
# * possible embedding in a web app

# %% [markdown]
# #### Now, I will show you how it is done ...

# %% [markdown]
# ## Step 0: Example Data

# %% [markdown]
# <img src=europython-2016-logo-white-bg.png width=400 />

# %% [markdown]
# <img src=twitter.png width=200 />

# %% [markdown]
# * tweets during Europython 2016 @europython
# * author will be linked with users mentioned in a tweet

# %% [markdown]
# ## Step 1: Create a Network

# %%
import networkx
from math import sqrt
network = networkx.read_gml('ep2016.gml')

layout = networkx.spring_layout(network,
                                k=1.1/sqrt(network.number_of_nodes()),
                                iterations=100)
# https://en.wikipedia.org/wiki/Force-directed_graph_drawing

# %% [markdown]
# ![elastic network](images/elastic_network.png)
#
# <sub>Image: https://en.wikipedia.org/wiki/Spring_system</sub>

# %% [markdown]
# * Only nice took look at
# * Flattened into 2D
# * Not accurate

# %% [markdown]
# ## The Cornerstone is the ColumnDataSource
#
# | (id)  | x   | y   | node_name | ... |
# |:-----:|:---:|:---:|:---------:|:---:|
# | 0     | 21  | 3   | da_bjoerni| ... |
# | 1     | 14  | 7   | user47    | ... |
# | ...   | ... | ... | ...       | ... |
#
# * column based data class
# * columns must be sequences of data e.g. lists, pandas.DataFrame, ...
# * changes will effect the plot during a rerendering
# * selection information inside a plot

# %%
from bokeh.models import ColumnDataSource

nodes, nodes_coordinates = zip(*sorted(layout.items()))
nodes_xs, nodes_ys = list(zip(*nodes_coordinates))
nodes_source = ColumnDataSource(dict(x=nodes_xs, y=nodes_ys,
                                     name=nodes))

# %% [markdown]
# ## Step 2: Plot a Network

# %%
from bokeh.plotting import show, figure
from bokeh.io import output_notebook
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[('name', '@name'), ('id', '$index')])
plot = figure(plot_width=800, plot_height=400,
              tools=['tap', hover, 'box_zoom', 'reset'])
r_circles = plot.circle('x', 'y', source=nodes_source, size=10,
                        color='blue', level = 'overlay')

# %%
output_notebook(); show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="768b6185-cb2f-40ae-a6b5-7cb3598fbdfd">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="269f28dc-f6dc-4f62-b6c2-ee4ddc55d41f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("269f28dc-f6dc-4f62-b6c2-ee4ddc55d41f").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("269f28dc-f6dc-4f62-b6c2-ee4ddc55d41f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '269f28dc-f6dc-4f62-b6c2-ee4ddc55d41f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"3bd27823-3cdb-4ffe-ab51-6ac516aabf71":{"roots":{"references":[{"attributes":{},"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"},{"attributes":{},"id":"1ad5faad-cd7f-4fb6-82f2-cb3313244b80","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"99914b38-9ba6-4eff-8b63-cbae39faa5d5","type":"HoverTool"},{"id":"4a3c50e2-9f80-4dac-a9f4-90c54de43a77","type":"TapTool"},{"id":"4f854363-e721-43dd-a76e-0d44f94eef3e","type":"BoxZoomTool"},{"id":"82a63ff4-c9d8-4622-a5b2-22bdfd29c43f","type":"ResetTool"}]},"id":"06c46a8d-e110-4333-b64d-19775452b1cc","type":"Toolbar"},{"attributes":{"formatter":{"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"65677e7b-6999-45fa-af31-99be2778f4fa","type":"LinearAxis"},{"attributes":{},"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e67b3f8f-7a41-4cb0-b7df-a3796fd0b0fe","type":"BasicTicker"}},"id":"8bd395a0-2599-480e-9cae-62c31b2f23d0","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"fdbd16a4-c52a-4268-af2f-0df7d7ff8fbb","type":"Grid"},{"attributes":{"data_source":{"id":"d65f5bee-783e-41ca-8b1b-cbd296a0b5a9","type":"ColumnDataSource"},"glyph":{"id":"759411bd-e297-4c2a-aaa3-b1f22c88dec2","type":"Circle"},"hover_glyph":null,"level":"overlay","nonselection_glyph":{"id":"6749b93b-f7c7-4c7c-8bbd-0c46f90ac1be","type":"Circle"},"selection_glyph":null},"id":"1d3117c5-4cb9-47c9-8d68-fbd4747629a0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["name","y","x"],"data":{"name":["100Commits","1337bullets","1st1","AartGoossens","AbletonDev","AdaTheShow","AergNuor","AishaXBello","Angel_Cruijff","Angelinux3000","ApacheAirflow","BBC","BBCmicrobit","BYAnalytics_en","BayesianHorse","BetabeersVG","BlueYonderTech","BokehPlots","BorsLTD","CAChemEorg","CIBBVA","Cambolc","Charles_JUDITH","CodingGrace","ContinuumIO","CriteoEng","DRMacIver","DZPM","DaniBot_","DanielDomeneL","DaryaChyzhyk","DasIstHerrKuska","DavidjMarkey","DeborahTaos12","DigitYasuhara","DjangoGirlsDUB","DjangoGirlsEP16","DjangoGirlsEc","EPfestival","ElnexoMarit","EmmaDelescolle","EnCuKou","EnriquetaSo","EntropyFarmer","Eurocentrique","EventGeekie","FAECTA_","FernanMilla","Fernandoo461","FlorianWilhelm","Foxinsock","GMLudo","GaelVaroquaux","Garrosa","GinnyGhezzo","GlaciarBlue","Glenio_Oliveira","GoolerES","GrandsCru","GsBitBalear","Gtzl","HashtagLaToya","HelloML9","HokstadConsult","HugoHerter","IKERGUNE","ITCrowdsource","IcanadasM","IldikoVancsa","ImaneElAzlouk","InspirefestHQ","JOANNALETIZIA","JancaStroma","JasmineMcTigue","Jaysinhp","JohaPrime","JoseOpposite","JuliaDrBa","KoehlerKerstin","Kyrish","LIGO","LaetitiaCarquet","Lanwe","LatitudeFest","Limejump","Luen","MBonell","Macario8","Madrid_Talent","MakingLyst","MarcoBasic","MariaDehn","MartaUhlirova","MassHaste","MaxBenChrist","Miau_DB","MiloslavPojman","MirkoDziadzka","MissPhilbin","MongoDB","MrsCaroline_C","N4h_H4N","NaomiCeder","NegoBide","NephilaIt","NeuroSky","NotANormalNerd","NowLivecodingtv","OReillyMedia","OpenAtWE","OpenStack","PCalcao","Patjouk","Pazqo","PiusNyongesa","Polyconseiltech","Ppuji1Ppuji","PyCharm_edu","PyConUK","PyData","PyLadiesDub","PythonEggs","PythonIreland","PythonSV","RLerallut","RORYCOLE90","RTFMCelia","RealPython","RedHatNews","Rhapsody_Girl","Rico858","SEReuskadi","STajbakhsh","SalamancaPeral","SaltStack","SaltStackInc","SancasDev","Sesivany","ShirleyYYoung","Sophie_Talent","SoyElCapi","Spanarchie","SparkyCZ","SrNilsson","StefanTuralski","StephLKim","Sustatu", ...

# %% [markdown]
# # Step 3: Add the edges
#
# ### Prepare the networkX edges

# %%
def get_edges_specs(_network, _layout):
    d = dict(xs=[], ys=[], alphas=[])
    weights = [d['weight'] for u, v, d in _network.edges(data=True)]
    max_weight = max(weights)
    calc_alpha = lambda h: 0.1 + 0.6 * (h / max_weight)

    # example: { ..., ('user47', 'da_bjoerni', {'weight': 3}), ... }
    for u, v, data in _network.edges(data=True):
        d['xs'].append([_layout[u][0], _layout[v][0]])
        d['ys'].append([_layout[u][1], _layout[v][1]])
        d['alphas'].append(calc_alpha(data['weight']))
    return d

# %% [markdown]
# ### Create a ColumnDataSource for the edges

# %%
lines_source = ColumnDataSource(get_edges_specs(network, layout))

# %%
r_lines = plot.multi_line('xs', 'ys', line_width=1.5,
                          alpha='alphas', color='navy',
                          source=lines_source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a2b971ce-8a5f-4d63-884b-186cf60645f9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("a2b971ce-8a5f-4d63-884b-186cf60645f9").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a2b971ce-8a5f-4d63-884b-186cf60645f9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a2b971ce-8a5f-4d63-884b-186cf60645f9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"859376f0-cd86-4f36-b6fd-252b3120f9a6":{"roots":{"references":[{"attributes":{},"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"},{"attributes":{},"id":"1ad5faad-cd7f-4fb6-82f2-cb3313244b80","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"99914b38-9ba6-4eff-8b63-cbae39faa5d5","type":"HoverTool"},{"id":"4a3c50e2-9f80-4dac-a9f4-90c54de43a77","type":"TapTool"},{"id":"4f854363-e721-43dd-a76e-0d44f94eef3e","type":"BoxZoomTool"},{"id":"82a63ff4-c9d8-4622-a5b2-22bdfd29c43f","type":"ResetTool"}]},"id":"06c46a8d-e110-4333-b64d-19775452b1cc","type":"Toolbar"},{"attributes":{"formatter":{"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"65677e7b-6999-45fa-af31-99be2778f4fa","type":"LinearAxis"},{"attributes":{},"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"field":"alphas"},"line_color":{"value":"navy"},"line_width":{"value":1.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"618ac647-f397-454a-8e31-c60c2026023e","type":"MultiLine"},{"attributes":{"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e67b3f8f-7a41-4cb0-b7df-a3796fd0b0fe","type":"BasicTicker"}},"id":"8bd395a0-2599-480e-9cae-62c31b2f23d0","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"fdbd16a4-c52a-4268-af2f-0df7d7ff8fbb","type":"Grid"},{"attributes":{"data_source":{"id":"d65f5bee-783e-41ca-8b1b-cbd296a0b5a9","type":"ColumnDataSource"},"glyph":{"id":"759411bd-e297-4c2a-aaa3-b1f22c88dec2","type":"Circle"},"hover_glyph":null,"level":"overlay","nonselection_glyph":{"id":"6749b93b-f7c7-4c7c-8bbd-0c46f90ac1be","type":"Circle"},"selection_glyph":null},"id":"1d3117c5-4cb9-47c9-8d68-fbd4747629a0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["name","y","x"],"data":{"name":["100Commits","1337bullets","1st1","AartGoossens","AbletonDev","AdaTheShow","AergNuor","AishaXBello","Angel_Cruijff","Angelinux3000","ApacheAirflow","BBC","BBCmicrobit","BYAnalytics_en","BayesianHorse","BetabeersVG","BlueYonderTech","BokehPlots","BorsLTD","CAChemEorg","CIBBVA","Cambolc","Charles_JUDITH","CodingGrace","ContinuumIO","CriteoEng","DRMacIver","DZPM","DaniBot_","DanielDomeneL","DaryaChyzhyk","DasIstHerrKuska","DavidjMarkey","DeborahTaos12","DigitYasuhara","DjangoGirlsDUB","DjangoGirlsEP16","DjangoGirlsEc","EPfestival","ElnexoMarit","EmmaDelescolle","EnCuKou","EnriquetaSo","EntropyFarmer","Eurocentrique","EventGeekie","FAECTA_","FernanMilla","Fernandoo461","FlorianWilhelm","Foxinsock","GMLudo","GaelVaroquaux","Garrosa","GinnyGhezzo","GlaciarBlue","Glenio_Oliveira","GoolerES","GrandsCru","GsBitBalear","Gtzl","HashtagLaToya","HelloML9","HokstadConsult","HugoHerter","IKERGUNE","ITCrowdsource","IcanadasM","IldikoVancsa","ImaneElAzlouk","InspirefestHQ","JOANNALETIZIA","JancaStroma","JasmineMcTigue","Jaysinhp","JohaPrime","JoseOpposite","JuliaDrBa","KoehlerKerstin","Kyrish","LIGO","LaetitiaCarquet","Lanwe","LatitudeFest","Limejump","Luen","MBonell","Macario8","Madrid_Talent","MakingLyst","MarcoBasic","MariaDehn","MartaUhlirova","MassHaste","MaxBenChrist","Miau_DB","MiloslavPojman","MirkoDziadzka","MissPhilbin","MongoDB","MrsCaroline_C","N4h_H4N","NaomiCeder","NegoBide","NephilaIt","NeuroSky","NotANormalNerd","NowLivecodingtv","OReillyMedia","OpenAtWE","OpenStack","PCalcao","Patjouk","Pazqo","PiusNyongesa","Polyconseiltech","Ppuji1Ppuji","PyCharm_edu","PyConUK","PyData","PyLadiesDub","PythonEggs","PythonIreland","PythonSV","RLerallut","RORYCOLE90","RTFMCelia","RealPython","RedHatNews","Rhapsody_Girl","Rico858","SE ...

# %% [markdown]
# # Step 4: Visualize properties
#
# ### Add Clustering and Centrality to ColumnDataSource

# %%
centrality =\
    networkx.algorithms.centrality.betweenness_centrality(network)
# first element are nodes again
_, nodes_centrality = zip(*sorted(centrality.items()))
max_centraliy = max(nodes_centrality)
nodes_source.add([7 + 10 * t / max_centraliy
                  for t in nodes_centrality],
                 'centrality')
# Out:
# 'centrality'

# %%
import community # python-louvain
partition = community.best_partition(network)
p_, nodes_community = zip(*sorted(partition.items()))
nodes_source.add(nodes_community, 'community')
community_colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628', '#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666']
nodes_source.add([community_colors[t % len(community_colors)]
                  for t in nodes_community],
                 'community_color')
# Out:
# 'community_color'

# %% [markdown]
# ### Update the Renderer

# %%
r_circles.glyph.size = 'centrality'
r_circles.glyph.fill_color = 'community_color'

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="08c708c4-afbc-4014-a539-be94f311e771"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("08c708c4-afbc-4014-a539-be94f311e771").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("08c708c4-afbc-4014-a539-be94f311e771");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '08c708c4-afbc-4014-a539-be94f311e771' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"701564d1-e07c-42ca-af9f-1ce145e27a58":{"roots":{"references":[{"attributes":{},"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"},{"attributes":{},"id":"1ad5faad-cd7f-4fb6-82f2-cb3313244b80","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"99914b38-9ba6-4eff-8b63-cbae39faa5d5","type":"HoverTool"},{"id":"4a3c50e2-9f80-4dac-a9f4-90c54de43a77","type":"TapTool"},{"id":"4f854363-e721-43dd-a76e-0d44f94eef3e","type":"BoxZoomTool"},{"id":"82a63ff4-c9d8-4622-a5b2-22bdfd29c43f","type":"ResetTool"}]},"id":"06c46a8d-e110-4333-b64d-19775452b1cc","type":"Toolbar"},{"attributes":{"formatter":{"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"65677e7b-6999-45fa-af31-99be2778f4fa","type":"LinearAxis"},{"attributes":{},"id":"4b9adfcf-7b24-4511-98dd-88c89adcf542","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"field":"alphas"},"line_color":{"value":"navy"},"line_width":{"value":1.5},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"618ac647-f397-454a-8e31-c60c2026023e","type":"MultiLine"},{"attributes":{"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"e67b3f8f-7a41-4cb0-b7df-a3796fd0b0fe","type":"BasicTicker"}},"id":"8bd395a0-2599-480e-9cae-62c31b2f23d0","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"8ab675fd-9e0c-48f5-98dc-719dedcb118c","subtype":"Figure","type":"Plot"},"ticker":{"id":"b65f7e05-e03a-4026-9c1b-7a161798ced7","type":"BasicTicker"}},"id":"fdbd16a4-c52a-4268-af2f-0df7d7ff8fbb","type":"Grid"},{"attributes":{"data_source":{"id":"d65f5bee-783e-41ca-8b1b-cbd296a0b5a9","type":"ColumnDataSource"},"glyph":{"id":"759411bd-e297-4c2a-aaa3-b1f22c88dec2","type":"Circle"},"hover_glyph":null,"level":"overlay","nonselection_glyph":{"id":"6749b93b-f7c7-4c7c-8bbd-0c46f90ac1be","type":"Circle"},"selection_glyph":null},"id":"1d3117c5-4cb9-47c9-8d68-fbd4747629a0","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["name","y","x","centrality","community","community_color"],"data":{"centrality":[7.0,7.0,7.0,7.0,7.0,7.052469537263125,7.019606349412263,7.033397348684591,7.0,7.00271448243777,7.00523694732652,7.000228938418451,7.0,7.0,7.0,7.0,7.005486018214819,7.000239491238749,7.009867039036465,7.0,7.001218531422755,7.0,7.0,7.0281517452554985,7.0182621440603485,7.000804690562197,7.0,7.0045304883584505,7.0,7.0,7.0,7.039698067735058,7.0125146261702485,7.00271448243777,7.0,7.012730576518651,7.000044705031233,7.0001387984779235,7.0,7.019636058766972,7.0,7.0,7.0,7.0,7.001261594228351,7.012359983042034,7.0,7.0,7.039698067735058,7.005141150831021,7.001199690062963,7.013857180855134,7.002771286174254,7.0,7.039698067735058,7.0,7.00271448243777,7.0,7.0,7.0,7.026199561111076,7.0,7.0,7.00271448243777,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.00012645137406,7.0,7.0,7.0,7.0,7.01981071526933,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.001235627412722,7.0,7.0,7.01981071526933,7.0,7.0,7.015089662881182,7.0,7.0,7.003327922918412,7.0,7.0,7.0000191592991,7.039698067735058,7.0,7.000323560948198,7.0,7.0429668320399745,7.0,7.0,7.039698067735058,7.0,7.009943676232864,7.0,7.0,7.0,7.000536460374798,7.012840491836861,7.0,7.000025545732133,7.0044324798801645,7.0,7.0,7.0,7.0,7.000204365857066,7.00001532743928,7.0,7.0,7.000249070888299,7.0,7.0,7.0,7.0,7.0,7.009142091187985,7.0,7.002982897386348,7.0,7.0,7.0,7.039698067735058,7.0,7.0000191592991,7.0,7.0,7.0,7.0045304883584505,7.002749590516367,7.0,7.0,7.0,7.0,7.009720998047497,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0,7.0003072786636595,7.000025545732133,7.0,7.029934058597925,7.0,7.006476750401555,7.039698067735058,7.0,7.000424059153412,7.039698067735058,7.0,7.0,7.0,7.0048384801240555,7.0,7.0,7.0,7.0,7.0000383185982,7.0,7.0,7.0097209980474 ...

# %% [markdown]
# # Step 5: Interactions

# %% [markdown]
# ### Get Selected Nodes
#
# `ColumnDataSource.selected`
# ```python
# {
#  # line or patch glyph selections
#  '0d': {'get_view': {}, 'glyph': None,
#         'indices': []},
#  # all other glyph selections
#  '1d': {'indices': [73]},
#  # [multi]line or patch selections
#  '2d': {'indices': []}
# }
# ```

# %% [markdown]
# ### Remove Node

# %%
def remove_node():
    idx = nodes_source.selected['1d']['indices'][0]
    
    # update networkX network
    node = nodes_source.data['name'][idx]
    network.remove_node(node)
    
    # update layout
    layout.pop(node)
    
    # update nodes ColumnDataSource
    new_source_data = dict()
    for column in nodes_source.column_names:
        new_source_data[column] =\
        [e for i, e in enumerate(nodes_source.data[column])
         if i != idx]
    nodes_source.data = new_source_data

    # update lines ColumnDataSource
    lines_source.data = get_edges_specs(network, layout)

# %% [markdown]
# ### Notebook Limitations
# * no direct redraw after changing the ColumnDataSource
# * getting selected nodes is not working
# * can not run arbitrary python code started by widges, e.g. buttons
#
# <br>
#
# ### Bokeh Server
# ```
# bokeh serve your_app.py
# ```
#
# [http://localhost:5006/bokehx_app](http://localhost:5006/bokehx_app)

# %% [markdown]
# # Thank You
#
# The slides and code can be found at:
#
# [https://github.com/blue-yonder/documents](https://github.com/blue-yonder/documents)
#
# <br>
# ## NetworkX
# [https://networkx.github.io](https://networkx.github.io)
#
# <br>
# ## Bokeh
# [http://bokeh.pydata.org](http://bokeh.pydata.org)
