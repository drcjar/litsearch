# %% [markdown]
# # NetworkX Visualization Powered by Bokeh
#
# <br>
# ### EuroPython 2016 (2016-07-22)
#
# ###### Björn Meier

# %% [markdown]
# ### Original Objectives:
# * exploring networks for patterns based on properties like node centrality or clustering
# * visualization in a browser
#
# <br>

# %% [markdown]
# ### Original Solution:
# * generate networks and properties
# * RESTful Flask app to provide data
# * D3.js app for browser visualization

# %% [markdown]
# ## Can we solve this easier?

# %% [markdown]
# ### NetworkX + Bokeh
#
# * define the visualization in pure python
# * interact with your network
#     * change views or change showed properties
#     * manipulate the network and get an updated plot
# * possible embedding in a web app

# %% [markdown]
# #### Now, I will show you how it is done ...

# %% [markdown]
# ## Step 0: Example Data

# %% [markdown]
# <img src=europython-2016-logo-white-bg.png width=400 />

# %% [markdown]
# <img src=twitter.png width=200 />

# %% [markdown]
# * tweets during Europython 2016 @europython
# * author will be linked with users mentioned in a tweet

# %% [markdown]
# ## Step 1: Create a Network

# %%
import networkx
from math import sqrt
network = networkx.read_gml('ep2016.gml')

layout = networkx.spring_layout(network,
                                k=1.1/sqrt(network.number_of_nodes()),
                                iterations=100)
# https://en.wikipedia.org/wiki/Force-directed_graph_drawing

# %% [markdown]
# ![elastic network](images/elastic_network.png)
#
# <sub>Image: https://en.wikipedia.org/wiki/Spring_system</sub>

# %% [markdown]
# * Only nice took look at
# * Flattened into 2D
# * Not accurate

# %% [markdown]
# ## The Cornerstone is the ColumnDataSource
#
# | (id)  | x   | y   | node_name | ... |
# |:-----:|:---:|:---:|:---------:|:---:|
# | 0     | 21  | 3   | da_bjoerni| ... |
# | 1     | 14  | 7   | user47    | ... |
# | ...   | ... | ... | ...       | ... |
#
# * column based data class
# * columns must be sequences of data e.g. lists, pandas.DataFrame, ...
# * changes will effect the plot during a rerendering
# * selection information inside a plot

# %%
from bokeh.models import ColumnDataSource

nodes, nodes_coordinates = zip(*sorted(layout.items()))
nodes_xs, nodes_ys = list(zip(*nodes_coordinates))
nodes_source = ColumnDataSource(dict(x=nodes_xs, y=nodes_ys,
                                     name=nodes))

# %% [markdown]
# ## Step 2: Plot a Network

# %%
from bokeh.plotting import show, figure
from bokeh.io import output_notebook
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[('name', '@name'), ('id', '$index')])
plot = figure(plot_width=800, plot_height=400,
              tools=['tap', hover, 'box_zoom', 'reset'])
r_circles = plot.circle('x', 'y', source=nodes_source, size=10,
                        color='blue', level = 'overlay')

# %%
output_notebook(); show(plot)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d14f6aba-3604-49c8-a6e8-490cde7cc61f">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b44acb32-c2f2-464b-9e61-ef2128639a95"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b44acb32-c2f2-464b-9e61-ef2128639a95").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b44acb32-c2f2-464b-9e61-ef2128639a95");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b44acb32-c2f2-464b-9e61-ef2128639a95' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"
type":"LinearAxis"}],"plot_height":400,"plot_width":800,"renderers":[{"id":"4d3ebcd6-4b7a-499e-9ac2-d876d5405b4e","type":"LinearAxis"},{"id":"ea6339f4-23ad-4ba0-8c96-ca04094e9e4d","type":"Grid"},{"id":"11666b73-0f1e-4bf1-9c40-12f905efd7b9","type":"LinearAxis"},{"id":"81642004-5323-4922-8f83-414c2b4340ce","type":"Grid"},{"id":"5cda5d3e-6a9c-4af6-b322-8b83fe85d2c8","type":"BoxAnnotation"},{"id":"fcce2042-c667-4e8e-aa81-908a920a30ca","type":"GlyphRenderer"}],"title":{"id":"e805994c-cd15-4688-9e44-9e5d06726f4f","type":"Title"},"tool_events":{"id":"3b146b95-78d2-4b0c-acde-a45e31f85ca9","type":"ToolEvents"},"toolbar":{"id":"7274e592-5dd6-41e7-aea2-d11d9368fe7e","type":"Toolbar"},"x_range":{"id":"ee8b5499-291b-4b76-beb2-688735c225f3","type":"DataRange1d"}," ...

# %% [markdown]
# # Step 3: Add the edges
#
# ### Prepare the networkX edges

# %%
def get_edges_specs(_network, _layout):
    d = dict(xs=[], ys=[], alphas=[])
    weights = [d['weight'] for u, v, d in _network.edges(data=True)]
    max_weight = max(weights)
    calc_alpha = lambda h: 0.1 + 0.6 * (h / max_weight)

    # example: { ..., ('user47', 'da_bjoerni', {'weight': 3}), ... }
    for u, v, data in _network.edges(data=True):
        d['xs'].append([_layout[u][0], _layout[v][0]])
        d['ys'].append([_layout[u][1], _layout[v][1]])
        d['alphas'].append(calc_alpha(data['weight']))
    return d

# %% [markdown]
# ### Create a ColumnDataSource for the edges

# %%
lines_source = ColumnDataSource(get_edges_specs(network, layout))

# %%
r_lines = plot.multi_line('xs', 'ys', line_width=1.5,
                          alpha='alphas', color='navy',
                          source=lines_source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="2da4166c-56ec-4bbf-9126-e87223550367"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("2da4166c-56ec-4bbf-9126-e87223550367").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2da4166c-56ec-4bbf-9126-e87223550367");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2da4166c-56ec-4bbf-9126-e87223550367' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2474a156-53cf-4e37-9163-d340aab74104":{"roots":{"references":[{"attributes":{"overlay":{"id":"5cda5d3e-6a9c-4af6-b322-8b83fe85d2c8","type":"BoxAnnotation"},"plot":{"id":"2dad7ae8-dc8a-4715-afb2-d4b60b396918","subtype":"Figure","type":"Plot"}},"id":"b881ea41-9e8c-4197-801e-74dc6c054608","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["xs","ys","alphas"],"data":{"alphas":[0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.20344827586206898,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.2655172413793103,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.24482758620689657,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.18275862068965518,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0. ...

# %% [markdown]
# # Step 4: Visualize properties
#
# ### Add Clustering and Centrality to ColumnDataSource

# %%
centrality =\
    networkx.algorithms.centrality.betweenness_centrality(network)
# first element are nodes again
_, nodes_centrality = zip(*sorted(centrality.items()))
max_centraliy = max(nodes_centrality)
nodes_source.add([7 + 10 * t / max_centraliy
                  for t in nodes_centrality],
                 'centrality')
# Out:
# 'centrality'

# %%
import community # python-louvain
partition = community.best_partition(network)
p_, nodes_community = zip(*sorted(partition.items()))
nodes_source.add(nodes_community, 'community')
community_colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628', '#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666']
nodes_source.add([community_colors[t % len(community_colors)]
                  for t in nodes_community],
                 'community_color')
# Out:
# 'community_color'

# %% [markdown]
# ### Update the Renderer

# %%
r_circles.glyph.size = 'centrality'
r_circles.glyph.fill_color = 'community_color'

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="fbb51dec-9b9c-4805-a1f6-94432a6a6faf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("fbb51dec-9b9c-4805-a1f6-94432a6a6faf").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("fbb51dec-9b9c-4805-a1f6-94432a6a6faf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'fbb51dec-9b9c-4805-a1f6-94432a6a6faf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"03614a79-c5b4-4923-af2d-5ede99aac579":{"roots":{"references":[{"attributes":{"overlay":{"id":"5cda5d3e-6a9c-4af6-b322-8b83fe85d2c8","type":"BoxAnnotation"},"plot":{"id":"2dad7ae8-dc8a-4715-afb2-d4b60b396918","subtype":"Figure","type":"Plot"}},"id":"b881ea41-9e8c-4197-801e-74dc6c054608","type":"BoxZoomTool"},{"attributes":{"callback":null,"column_names":["xs","ys","alphas"],"data":{"alphas":[0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.20344827586206898,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.2655172413793103,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.24482758620689657,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.18275862068965518,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0. ...

# %% [markdown]
# # Step 5: Interactions

# %% [markdown]
# ### Get Selected Nodes
#
# `ColumnDataSource.selected`
# ```python
# {
#  # line or patch glyph selections
#  '0d': {'get_view': {}, 'glyph': None,
#         'indices': []},
#  # all other glyph selections
#  '1d': {'indices': [73]},
#  # [multi]line or patch selections
#  '2d': {'indices': []}
# }
# ```

# %% [markdown]
# ### Remove Node

# %%
def remove_node():
    idx = nodes_source.selected['1d']['indices'][0]
    
    # update networkX network
    node = nodes_source.data['name'][idx]
    network.remove_node(node)
    
    # update layout
    layout.pop(node)
    
    # update nodes ColumnDataSource
    new_source_data = dict()
    for column in nodes_source.column_names:
        new_source_data[column] =\
        [e for i, e in enumerate(nodes_source.data[column])
         if i != idx]
    nodes_source.data = new_source_data

    # update lines ColumnDataSource
    lines_source.data = get_edges_specs(network, layout)

# %% [markdown]
# ### Notebook Limitations
# * no direct redraw after changing the ColumnDataSource
# * getting selected nodes is not working
# * can not run arbitrary python code started by widges, e.g. buttons
#
# <br>
#
# ### Bokeh Server
# ```
# bokeh serve your_app.py
# ```
#
# [http://localhost:5006/bokehx_app](http://localhost:5006/bokehx_app)

# %% [markdown]
# # Thank You
#
# The slides and code can be found at:
#
# [https://github.com/blue-yonder/documents](https://github.com/blue-yonder/documents)
#
# <br>
# ## NetworkX
# [https://networkx.github.io](https://networkx.github.io)
#
# <br>
# ## Bokeh
# [http://bokeh.pydata.org](http://bokeh.pydata.org)
