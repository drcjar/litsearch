# %% [markdown]
# ### A notebook to support academic question exploration and literature search / what do you do when you search the literature?
#
# 0. Define a research question e.g Is occupational **asbestos exposure** an underecognised **cause** of IPF?
# 1. Consider the different possible ways of answering the question (methods). Different study designs and ways of measuring asbestos exposure e.g Epidemiological, observational, cross-sectional, cohort, case-control, post-mortem and explant studies, ecological, toxicology, animal models, molecular disease models, exposure assessment, occupational hygeinst measurements, minerologic analysis (tissue, BAL etc)
# 2. Generate search terms e.g "IPF", "case-control", "occupational", "asbestos" (? && mesh terms)
# 3. Carry out search using search terms and e.g pubmed, embase, google scholar, scopus, biorxiv, web of science, clinicaltrials.gov, ?google books, prepubmed.org, pubpeer.com
# 4. Search results == Candidate Papers
# 5. Extract title | journal | author | location | year | abstract | key words | full text && save result (as .bib) (prob want to export to jabref) https://stackoverflow.com/questions/30768745/is-there-a-reliable-python-library-for-taking-a-bibtex-entry-and-outputting-it-i
# 6. Review Candidate Papers to identify Relevant Papers
# 7. Use Relevant Papers to identify more Candidate papers. Search also by author, cited by, cite, [triangle closing](https://en.wikipedia.org/wiki/Triadic_closure) e.g https://github.com/hinnefe2/bibcheck.py and other means (?tensorflow/scikit-learn,nltk), https://en.wikipedia.org/wiki/Jaccard_index, networkx?
# 8. Use the Relevant Papers collected for whatever it is they are relevant for (usually to help compose a written document in which they are cited). Including exporting to a nice table for LaTeX.
# 9. ?django app times
#
# general discussion of the problem: 1. http://drugmonkey.scientopia.org/2010/09/28/on-keeping-abreast-of-the-literature-a-highly-loaded-poll-question/ 2. http://www.sciencemag.org/careers/2016/11/how-keep-scientific-literature
#
# meta: github/stack exchange etc to check out other peoples search strategies. this is likely to be formulated as a machine learning problem somewhere.

# %% [markdown]
# #### interesting related I found includes: https://www.projectcredo.com/, http://citationexplorer.hoppmann.me/, lict from a previous nhshackday, https://github.com/jvoytek/pubmedbrain/blob/f5170a2e3540e0c2aa665559c86048dfb1583f16/documents/Voytek-brainSCANrPreprint.pdf, https://github.com/graeham/hackathon/blob/master/paperGraph.py

# %% [markdown]
# ### search github for relevant stuff with the following 'webbit'
# > https://github.com/search?l=Python&q=http%3A%2F%2Feutils.ncbi.nlm.nih.gov%2Fentrez%2Feutils%2Fesearch.fcgi++stars%3A%3E5&ref=advsearch&type=Code&utf8=%E2%9C%93
#
# gists and interwebs inc stackoverflow also helpful

# %% [markdown]
# tempting to dive into django a la https://github.com/afouchet/OpenReview but probably not essential and now is not optimal timing

# %% [markdown]
# https://github.com/gui11aume looks well documented, poss useful template
# https://github.com/swcarpentry/2013-08-23-harvard/blob/b2097bc20833e0a58b2e73eecd1227d61bd5a00a/lessons/misc-biopython/eutils.md looks like nice intro to biopython utils and https://gist.github.com/bonzanini/5a4c39e4c02502a8451d, https://gist.github.com/ehazlett/1104507, https://gist.github.com/vtrubets/ef1dabb397ea6a05ce5b4e767ed15af9 (for use of icite), https://gist.github.com/mcfrank/c1ec74df1427278cbe53, http://stackoverflow.com/questions/17409107/obtaining-data-from-pubmed-using-python, https://github.com/bwallace/abstrackr-web/tree/master/abstrackr, http://www.billconnelly.net/?p=44

# %% [markdown]
# ### let's tackle pubmed first

# %%
"""
Notebook to support academic question exploration and literature search.

Thanks to https://marcobonzanini.wordpress.com/2015/01/12/searching-pubmed-with-python/ and 
http://www.fredtrotter.com/2014/11/14/hacking-on-the-pubmed-api/ and vtrubets
https://gist.github.com/vtrubets/ef1dabb397ea6a05ce5b4e767ed15af9 

Pubmed advanced search is helpful for designing search/experimenting 
https://www.ncbi.nlm.nih.gov/pubmed/advanced

Docs for NCBI esearch:
https://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch
https://www.nlm.nih.gov/bsd/mms/medlineelements.html
"""
# Out:
# '\nNotebook to support academic question exploration and literature search.\n\nThanks to https://marcobonzanini.wordpress.com/2015/01/12/searching-pubmed-with-python/ and \nhttp://www.fredtrotter.com/2014/11/14/hacking-on-the-pubmed-api/ and vtrubets\nhttps://gist.github.com/vtrubets/ef1dabb397ea6a05ce5b4e767ed15af9 \n\nPubmed advanced search is helpful for designing search/experimenting \nhttps://www.ncbi.nlm.nih.gov/pubmed/advanced\n\nDocs for NCBI esearch:\nhttps://www.ncbi.nlm.nih.gov/books/NBK25499/#chapter4.ESearch\nhttps://www.nlm.nih.gov/bsd/mms/medlineelements.html\n'

# %%
from Bio import Entrez
from Bio import Medline
from tqdm import tqdm
from collections import Counter, OrderedDict
import json
import requests
import re
import pandas as pd
import pickle 
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx
# %matplotlib inline
# Out:
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
def get_chunked_pmids(term, chunksize=50):
    """
    Return a list of Pubmed ids from pubmed search in chunks
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    count_handle = Entrez.esearch(db="pubmed",
                                  term=term,
                                  retmode="xml",
                                  rettype="count")
    count_results = Entrez.read(count_handle)
    count = int(count_results["Count"])

    retmax_requests = list(range(chunksize, count, chunksize))
    retmax_requests.append(count - retmax_requests[len(retmax_requests) - 1])

    for i, retmax in enumerate(retmax_requests):
        pmid_handle = Entrez.esearch(db="pubmed",
                                     term=term,
                                     sort="relevance",
                                     retmode="xml",
                                     usehistory='y',
                                     retstart=retmax,
                                     retmax=chunksize)
        results = Entrez.read(pmid_handle)
        yield results["IdList"]

# %%
def get_pubmed_summaries(pubmed_id):
    """
    Use the Pubmed API to return a json summary of a list of pmid strings 
    """
    pubmed_id = ','.join(pubmed_id) # citation api likes to take a single string

    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.esummary(db='pubmed', 
                             id=pubmed_id, 
                             retmode='json',
                             rettype='abstract')
    return json.loads(handle.read())['result']

# %%
def get_pubmed_keywords(pubmed_id):
    """
    Use the Pubmed API to return the medline record and extract the key words for each pmid in a
    a list of pmid strings. Returns {pmid:[list of keywords]}.
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.efetch(db='pubmed',
                           id=pubmed_id,
                           rettype='medline',
                           retmode='text')
    records = Medline.parse(handle)
    keywords = {}
    for record in records:
        pmid = record.get('PMID','?')
        mh = record.get('MH','?')
        keywords[pmid] = mh
    return keywords

# %%
def get_pubmed_abstracts(pubmed_id):
    """
    Use the Pubmed API to return the medline record and extract the abstract for each pmid in a list
    of pmid strings. Return {pmid:abstract}.
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.efetch(db='pubmed',
                           id=pubmed_id,
                           rettype='medline',
                           retmode='text')
    records = Medline.parse(handle)
    abstracts = {}
    for record in records:
        pmid = record.get('PMID','?')
        ab = record.get('AB','?')
        abstracts[pmid] = ab
    return abstracts

# %%
def get_pubmed_pubtypes(pubmed_id):
    """
    Use the Pubmed API to return the medline record and extract the publication type for each pmid
    in a list of pmid strings. Return {pmid:pubtype}.
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.efetch(db='pubmed',
                           id=pubmed_id,
                           rettype='medline',
                           retmode='text')
    records = Medline.parse(handle)
    pubtypes = {}
    for record in records:
        pmid = record.get('PMID','?')
        pt = record.get('PT','?')
        pubtypes[pmid] = pt
    return pubtypes

# %%
def get_citation_information(pubmed_id):
    """
    Use the special citation api to return relative citation ratios
    Takes a list of pmid strings. Returns {pmid:rcr}
    (what rcr is http://journals.plos.org/plosbiology/article?id=10.1371/journal.pbio.1002541)
    """
    pubmed_id = ','.join(pubmed_id) # citation api likes to take a single string
    citation_search = 'https://icite.od.nih.gov/api/pubs?pmids={0}'.format(pubmed_id)
    response = requests.get(citation_search).content
    str_response = response.decode('utf-8')
    
    try:
        data = json.loads(str_response)['data']
    except KeyError:
        data = False
         
    citations = {}
    
    if data:
        for record in data:
            pmid = record.get('pmid')
            rcr = record.get('relative_citation_ratio')
            citations[pmid] = rcr
    return citations

# %%
def get_pmids_for_papers_citing(pubmed_id):
    """
    Use the Pubmed API to return a list of pmids for a paper citing a *single pmid*
    Return list of citing pmids.
    see also https://www.ncbi.nlm.nih.gov/pmc/tools/cites-citedby/
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.elink(dbfrom="pubmed",
                          id=pubmed_id,
                          linkname="pubmed_pubmed_citedin")
    records = Entrez.read(handle)
    list_of_pmids_citing = []
    
    if records[0]["LinkSetDb"]:
        for link in records[0]["LinkSetDb"][0]["Link"]:
            list_of_pmids_citing.append(link["Id"]) 
  
    return list_of_pmids_citing

# %%
def get_pmids_for_papers_cited(pubmed_id):
    """
    Use the Pubmed API to return a list of pmids for papers cited by a particular pmid
    Return list of pmids. *only works for papers in pubmed central*
    see also https://www.ncbi.nlm.nih.gov/pmc/tools/cites-citedby/
    """
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.elink(dbfrom="pubmed",
                          id=pubmed_id,
                          linkname="pubmed_pubmed_refs")
    records = Entrez.read(handle)
    list_of_pmids_cited = []
    
    if records[0]["LinkSetDb"]:
        for link in records[0]["LinkSetDb"][0]["Link"]:
            list_of_pmids_cited.append(link["Id"]) 
    return list_of_pmids_cited

# %%
def get_cited_pmids(pubmed_id):
    """
    Use the Pubmed API to return a list of pmids for a paper cited by pmid
    in a list of pmids. Return {pmid:list_of_citing_pmids}
    Only works for papers in PMC
    """
    cited = {}
    for pmid in pubmed_id:
        cited[pmid] = get_pmids_for_papers_cited(pmid)
    return cited

# %%
def get_citing_pmids(pubmed_id):
    """
    Use the Pubmed API to return a list of pmids for a paper citing a pmid
    in a list of pmids
    Return {pmid:list_of_citing_pmids}
    """
    citing = {}
    for pmid in pubmed_id:
        citing[pmid] = get_pmids_for_papers_citing(pmid)
  
    return citing

# %%
def lit_fetch(pubmed_id):
    """
    Search pubmed for a list of pmid strings and return information about the results
    """
    result = {}
    result['summaries'] = get_pubmed_summaries(pubmed_id)
    result['pubtypes'] = get_pubmed_pubtypes(pubmed_id)
    result['abstracts'] = get_pubmed_abstracts(pubmed_id)
    result['keywords'] = get_pubmed_keywords(pubmed_id)
    result['rcrs'] = get_citation_information(pubmed_id)
    result['citing'] = get_citing_pmids(pubmed_id)
    result['cited'] = get_cited_pmids(pubmed_id)
    return result

# %%
def resultdf(r):
    df = pd.DataFrame(r['summaries']['uids'], columns=['pmid'])
    df['title'] = df['pmid'].map(lambda x: r['summaries'].get(x)['title'])
    df['firstauthor'] = df['pmid'].map(lambda x: r['summaries'].get(x)['sortfirstauthor'])
    df['lastauthor'] = df['pmid'].map(lambda x: r['summaries'].get(x)['lastauthor'])
    df['journal'] = df['pmid'].map(lambda x: r['summaries'].get(x)['source'])
    df['pubdate'] = df['pmid'].map(lambda x: r['summaries'].get(x)['sortpubdate'])
    df['pubtype'] = df['pmid'].map(lambda x: r['pubtypes'].get(x))
    df['abstract'] = df['pmid'].map(lambda x: r['abstracts'].get(x))
    df['keywords'] = df['pmid'].map(lambda x: r['keywords'].get(x))
    df['rcr'] = df['pmid'].astype(int).map(lambda x: r['rcrs'].get(x))
    df['citedby'] =  df['pmid'].map(lambda x: r['citing'].get(x))
    df['cites'] = df['pmid'].map(lambda x: r['cited'].get(x))
    pd.set_option('max_colwidth',300)
    return df

# %%
def save_df_as_csv(term, df):
    name = term.replace(" ", "-")
    df.to_csv(name+".csv")

# %%
def lit_search(term):
    """
    Search pubmed for a term and collect information about the results
    """
    pmid_blocks = get_chunked_pmids(term, chunksize=200)
    df_list = []
    for i, block in enumerate(pmid_blocks):
        if i < 1:
            print("Beginning block processing")
            result = lit_fetch(block)
            df = resultdf(result)
            df_list.append(df)
            print("Processed block {0}".format(i))
    df = pd.concat(df_list)
    save_df_as_csv(term, df)
    return df

# %%
def explore_result_dataframe(df):
    """
    Print some simple stats for result dataframe
    """
    print('Top first authors\n')
    print(df.firstauthor.value_counts().head())
    print('\nTop last authors\n')
    print(df.lastauthor.value_counts().head())
    print('\nTop journals\n')
    print(df.journal.value_counts().head())
    print('\nTop publication types\n')
    print(df.pubtype.astype(str).value_counts().head())
    print('\nPublications per year\n')
    df.pubdate = pd.to_datetime(df.pubdate)
    df.index = df.pubdate
    df.groupby(df.pubdate.map(lambda x: x.year)).pmid.count().plot(kind='bar')

# %%
def jaccard(s1, s2):
    " takes two lists as input and returns Jaccard coefficient"
    st1=set(s1)
    st2=set(s2)
    u = set(st1).union(st2)
    i = set(st1).intersection(st2)
    return len(i)/len(u)

# %%
# df = lit_search('idiopathic pulmonary fibrosis')
df = pd.read_csv('idiopathic-pulmonary-fibrosis.csv')
explore_result_dataframe(df)
# Out:
# Top first authors
#
# Raghu G        44
# Cottin V       42
# Behr J         27
# Selman M       27
# Antoniou KM    24
# Name: firstauthor, dtype: int64
#
# Top last authors
#
# Collard HR    46
# Wells AU      43
# Bouros D      42
# Raghu G       41
# Crystal RG    39
# Name: lastauthor, dtype: int64
#
# Top journals
#
# Am J Respir Crit Care Med    397
# Chest                        273
# Eur Respir J                 268
# Respir Med                   158
# Thorax                       144
# Name: journal, dtype: int64
#
# Top publication types
#
# ['Journal Article']                                        1813
# ['Journal Article', "Research Support, Non-U.S. Gov't"]     929
# ['Journal Article', 'Review']                               729
# ['Case Reports', 'Journal Article']                         331
# ['English Abstract', 'Journal Article']                     251
# Name: pubtype, dtype: int64
#
# Publications per year

# %%
pmid_blocks = get_chunked_pmids('idiopathic pulmonary fibrosis', chunksize=200)

# %%
terms = ['idiopathic pulmonary fibrosis', 'cryptogenic fibrosing alveolitis',
        'usual interstitial pneumonia', 'asbestosis']

#?(idiopathic pulmonary fibrosis) AND (asbestos) 

def litsearch_terms(terms):
    """
    Search pubmed for the terms and return a df
    """
    df_list = []
    for term in terms:
        print ('searching for {0}'.format(term))
        df = lit_search(term)
        df_list.append(df)
        save_df_as_csv(term, df)
    df = pd.concat(df_list)
    return df

# %%
topic_collection = {"ipfjes_case_control_studies" : ['23022860', '10968375', '24413348', '19782552', '17628464', 
                                                     '10841131', '8569361', '8087336', '15640309', '9571528', 
                                                     '18507288', '2249047', '28157473', '21917441'], 
                    "ipfjes_reviews" : ['25621562', '24348069', '10193340', '11816818', '15331187', '16733403', '16738192'],
                   }

def litfetch_topic(topic, pmids):
    """
    fetch info for pmids in a topic and save the result as a .csv
    """
    print('begining topic {0} analaysis'.format(topic))
    result = lit_fetch(pmids)
    df = resultdf(result)
    save_df_as_csv(topic, df)
    print('csv of topic {0} saved'.format(topic))

# %%
def citing_count(pubmed_id):
    '''
    Looks up papers citing a list of pubmed_id strings and returns a dict
    {citing_paper:number_of_times_cites_list}
    '''
    citing = get_citing_pmids(pubmed_id)
    corpus = []
    for record in citing:
        corpus.append(citing[record])
    corpus = [item for sublist in corpus for item in sublist]
    x = Counter(corpus)
    citingpapers = [(l,k) for k,l in sorted([(j,i) for i,j in x.items()], reverse=True)]
    citing_count = dict(citingpapers)
    return citing_count

# %%
def jaccard_table(df):
    df1 = df[df.cites != '[]'] 
    # make a dataframe of papers that 
    # we have citation info for (ones in pmc)
    
    # eval to get list out of string
    # lets just work with this
    df2 = df1[['pmid', 'citedby']]
    
    # make the string of a list a list
    df2.citedby = df2.citedby.map(eval)
    
    # make a tidy dataframe
    df3 = pd.concat([df2.drop(['citedby'], axis=1), df2.citedby.apply(pd.Series)], axis=1)
    df4 = pd.melt(df3, id_vars='pmid')
    df4.drop('variable', axis=1, inplace=True)
    df4.columns = ['pmid', 'citedby']
    
    # adds a 'whichcites' column
    df4['whichcites'] = df4['citedby'].map(lambda x: get_cited_pmids([x]).values())
    
    # makes our which cites dict_lists single list lists
    df4.whichcites = df4.whichcites.map(list)
    df4.whichcites = df4.whichcites.map(lambda x: x.pop())
    
    # add cites column back in
    df5 = pd.merge(df1[['pmid', 'cites']], df4, on='pmid')
    
    # make list string a list
    df5.cites = df5.cites.map(eval)
    
    # make pmid values be str
    df5.pmid = df5.pmid.astype(str)
    
    # make citedby values be str
    df5.citedby = df5.citedby.astype(str)
    
    # add jaccard column
    df5['jaccard'] = 0
    for i in range(len(df5)):
        df5['jaccard'].iloc[i] = jaccard(df5.cites.iloc[i], df5.whichcites.iloc[i])
        
    return df5

# %%
def jaccard_tabledf(jaccard_table):
    df = jaccard_table.sort_values(by='jaccard', ascending=False)
    df = df[df['citedby'] != 'nan']
    r = lit_fetch(list(df.pmid.unique()))
    df['seed paper'] = df['pmid'].map(lambda x: r['summaries'].get(x)['title'])
    
    r = lit_fetch(list(df.citedby))
    df['title'] = df['citedby'].map(lambda x: r['summaries'].get(x)['title'])
    df['firstauthor'] = df['citedby'].map(lambda x: r['summaries'].get(x)['sortfirstauthor'])
    df['lastauthor'] = df['citedby'].map(lambda x: r['summaries'].get(x)['lastauthor'])
    df['journal'] = df['citedby'].map(lambda x: r['summaries'].get(x)['source'])
    df['pubdate'] = df['citedby'].map(lambda x: r['summaries'].get(x)['sortpubdate'])
    df['pubtype'] = df['citedby'].map(lambda x: r['pubtypes'].get(x))
    df['keywords'] = df['citedby'].map(lambda x: r['keywords'].get(x))
    df['rcr'] = df['citedby'].astype(int).map(lambda x: r['rcrs'].get(x))
    
    return df[['citedby', 'title', 'firstauthor', 'lastauthor', 'journal', 
              'pubdate', 'pubtype', 'rcr', 'jaccard']]

# %%
# litfetch_topic("ipfjes case control studies", topic_collection['ipfjes_case_control_studies'])

# %%
litfetch_topic("ipfjes review articles", topic_collection['ipfjes_reviews'])
# Out:
# begining topic ipfjes review articles analaysis
# csv of topic ipfjes review articles saved

# %%
df = pd.read_csv('ipfjes-case-control-studies.csv', usecols=['pmid','title','firstauthor','lastauthor',
                                                             'journal','pubdate','pubtype',
                                                             'abstract', 'keywords', 'rcr', 'citedby', 'cites'])

# %%
df = pd.read_csv('ipfjes-case-control-studies.csv', usecols=['pmid','title','firstauthor','lastauthor',
                                                             'journal','pubdate','pubtype',
                                                             'abstract', 'keywords', 'rcr', 'citedby', 'cites'])

df.pubdate = pd.to_datetime(df.pubdate)
df.year = df.pubdate.map(lambda x: x.year)
df['First author, year'] = df.firstauthor + ', ' + df.year.astype(str)
df['Title'] = df.title
df['Journal'] = df.journal
df = df.sort_values(by = 'pubdate', ascending=True)
df = df[['First author, year', 'Title', 'Journal']]
print(df.to_latex(index = False))
# Out:
# \begin{tabular}{lll}
# \toprule
#               First author, year &                                                                                                                                    Title &                     Journal \\
# \midrule
#                    Scott J, 1990 &                                    What causes cryptogenic fibrosing alveolitis? A case-control study of environmental exposure to dust. &                         BMJ \\
#                     Iwai K, 1994 &                                                        Idiopathic pulmonary fibrosis. Epidemiologic approaches to occupational exposure. &   Am J Respir Crit Care Med \\
#                  Hubbard R, 1996 &                                           Occupational exposure to metal or wood dust and aetiology of cryptogenic fibrosing alveolitis. &                      Lancet \\
#                   Mullen J, 1998 &                                                         Case-control study of idiopathic pulmonary fibrosis and environmental exposures. &         J Occup Environ Med \\
#                  Hubbard R, 2000 &                                                                               Risk of cryptogenic fibrosing alveolitis in metal workers. &                      Lancet \\
#             Baumgartner KB, 2000 &  Occupational and environmental risk factors for idiopathic pulmonary fibrosis: a multicenter case-control study. Collaborating Centers. &              Am J Epidemiol \\
#                   Miyake Y, 2005 &                                                       Occupational and environmental factors and idiopathic pulmonary fibrosis in Japan. &               Ann Occup Hyg \\
#                Gustafson T, 2007 &                                                                                     Occupational exposure and severe pulmonary fibrosis. &                  Respir Med \\
#                Pinheiro GA, 2008 &                                                     Occupational risks for idiopathic pulmonary fibrosis mortality in the United States. &  Int J Occup Environ Health \\
#  García-Sancho Figueroa MC, 2010 &                                            Risk factors for idiopathic pulmonary fibrosis in a Mexican population. A case-control study. &                  Respir Med \\
#            García-Sancho C, 2011 &                                              Familial pulmonary fibrosis is the strongest risk factor for idiopathic pulmonary fibrosis. &                  Respir Med \\
#                Awadalla NJ, 2012 &                Occupational and environmental risk factors for idiopathic pulmonary fibrosis in Egypt: a multicenter case-control study. &     Int J Occup Environ Med \\
#                  Ekström M, 2014 &    Effects of smoking, gender and occupational exposure on the risk of severe pulmonary fibrosis: a population-based case-control study. &                    BMJ Open \\
#                     Koo JW, 2017 &                                      Occupational exposure and idiopathic pulmonary fibrosis: a multicentre case-control study in Korea. &       Int J Tuberc Lung Dis \\
# \bottomrule
# \end{tabular}

# %%
df = pd.read_csv('ipfjes-review-articles.csv', usecols=['pmid','title','firstauthor','lastauthor',
                                                             'journal','pubdate','pubtype',
                                                             'abstract', 'keywords', 'rcr', 'citedby', 'cites'])

df.pubdate = pd.to_datetime(df.pubdate)
df.year = df.pubdate.map(lambda x: x.year)
df['First author, year'] = df.firstauthor + ', ' + df.year.astype(str)
df['Title'] = df.title
df['Journal'] = df.journal
df = df.sort_values(by = 'pubdate', ascending=True)
df = df[['First author, year', 'Title', 'Journal']]
print(df.to_latex(index = False))
# Out:
# \begin{tabular}{lll}
# \toprule
#      First author, year &                                                                                           Title &             Journal \\
# \midrule
#  Turner-Warwick M, 1998 &  In search of a cause of cryptogenic fibrosing alveolitis (CFA): one initiating factor or many? &              Thorax \\
#         Hubbard R, 2001 &               Occupational dust exposure and the aetiology of cryptogenic fibrosing alveolitis. &  Eur Respir J Suppl \\
#         Glazer CS, 2004 &                                                         Occupational interstitial lung disease. &      Clin Chest Med \\
#        De Vuyst P, 2006 &                                                       [Occupational interstitial lung disease]. &      Rev Mal Respir \\
#         Taskar VS, 2006 &                                      Is idiopathic pulmonary fibrosis an environmental disease? &  Proc Am Thorac Soc \\
#             Ley B, 2013 &                                                  Epidemiology of idiopathic pulmonary fibrosis. &      Clin Epidemiol \\
#          Gulati M, 2015 &                            Asbestosis and environmental causes of usual interstitial pneumonia. &  Curr Opin Pulm Med \\
# \bottomrule
# \end{tabular}

# %%
keywords = get_pubmed_keywords(topic_collection['ipfjes_case_control_studies'])

print ('Top pubmed keywords (mesh headings)',
       'for the {0} occupational IPF case-control studies found'.format(len(keywords)))

corpus = []
       
for record in keywords:
    corpus.append(keywords[record])
    
corpus = [item for sublist in corpus for item in sublist]

x = Counter(corpus)

top_keywords = [(l,k) for k,l in sorted([(j,i) for i,j in x.items()], reverse=True)]
top_keywords[:5]
# Out:
# Top pubmed keywords (mesh headings) for the 14 occupational IPF case-control studies found
# [('Male', 13),
#  ('Humans', 13),
#  ('Female', 13),
#  ('Case-Control Studies', 11),
#  ('Aged', 9)]

# %%
def citingpaperdf():
    cc = citing_count(topic_collection['ipfjes_case_control_studies'])
    result = lit_fetch(list(cc.keys()))
    df = resultdf(result)
    df.pubdate = pd.to_datetime(df.pubdate)
    df.index = df.pubdate.map(lambda x: x.year)
    df = df.sort_values(by = 'pubdate', ascending=True)
    df['citations of pmidgrp'] = df.pmid.map(lambda x: cc.get(x))
    df = df[['title','firstauthor', 'lastauthor', 'journal', 'pubtype', 'rcr', 'citations of pmidgrp']]
    df.to_csv('papers_citing_ipf_occupational_dust_case_control_studies.csv')
    return df

# %%
#citingpaperdf()

# %%
# G = nx.DiGraph(nx.from_dict_of_lists(citing))
citing = get_citing_pmids(topic_collection['ipfjes_case_control_studies'])

citing = OrderedDict(sorted(citing.items(), key=lambda t: len(t[1])))

citing = OrderedDict(reversed(list(citing.items())))

G = nx.from_dict_of_lists(citing)

pos=nx.spring_layout(G)

l = list(citing.keys())
r = get_citation_information(l)
rcrs = [r.get(int(e)) for e in l]
ns1 = [0 if v is None else v for v in rcrs]

    
nx.draw_networkx_nodes(G,pos,
                       nodelist=citing.keys(),
                       node_color='r',
                       node_size=[i * 50 for i in ns1],
                       alpha=0.8)

l = [item for sublist in citing.values() for item in sublist]
r = get_citation_information(l)
rcrs = [r.get(int(e)) for e in l]
ns2 = [0 if v is None else v for v in rcrs]


nx.draw_networkx_nodes(G,pos,
                       nodelist=[item for sublist in citing.values() for item in sublist],
                       node_color='b',
                       node_size=[i * 50 for i in ns2],
                       alpha=0.8)

nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)

labels = {}

for i, item in enumerate(citing):
    labels[item] = '*'
    
nx.draw_networkx_labels(G,pos,labels,font_size=8)

print ('IPF case-control studies and their citing papers (node size scaled to relative citation ratio)\n')
    
    
print ('Key : pubmed id : title author year : (n of citations)')

for i, item in enumerate(citing):
    print(i,':', item, ':', get_pubmed_summaries([item])[item]['title'],
          get_pubmed_summaries([item])[item]['sortfirstauthor'], 
          get_pubmed_summaries([item])[item]['sortpubdate'][:4],
          '({0})'.format(len(citing[item])))
    
plt.savefig('PapersThatIPFCaseControlStudies.eps')
# Out:
# IPF case-control studies and their citing papers (node size scaled to relative citation ratio)
#
# Key : pubmed id : title author year : (n of citations)
# 0 : 8569361 : Occupational exposure to metal or wood dust and aetiology of cryptogenic fibrosing alveolitis. Hubbard R 1996 (42)
# 1 : 10968375 : Occupational and environmental risk factors for idiopathic pulmonary fibrosis: a multicenter case-control study. Collaborating Centers. Baumgartner KB 2000 (41)
# 2 : 8087336 : Idiopathic pulmonary fibrosis. Epidemiologic approaches to occupational exposure. Iwai K 1994 (32)
# 3 : 2249047 : What causes cryptogenic fibrosing alveolitis? A case-control study of environmental exposure to dust. Scott J 1990 (25)
# 4 : 21917441 : Familial pulmonary fibrosis is the strongest risk factor for idiopathic pulmonary fibrosis. García-Sancho C 2011 (17)
# 5 : 15640309 : Occupational and environmental factors and idiopathic pulmonary fibrosis in Japan. Miyake Y 2005 (12)
# 6 : 19782552 : Risk factors for idiopathic pulmonary fibrosis in a Mexican population. A case-control study. García-Sancho Figueroa MC 2010 (10)
# 7 : 10841131 : Risk of cryptogenic fibrosing alveolitis in metal workers. Hubbard R 2000 (9)
# 8 : 18507288 : Occupational risks for idiopathic pulmonary fibrosis mortality in the United States. Pinheiro GA 2008 (8)
# 9 : 23022860 : Occupational and environmental risk factors for idiopathic pulmonary fibrosis in Egypt: a multicenter case-control study. Awadalla NJ 2012 (6)
# 10 : 17628464 : Occupational exposure and severe pulmonary fibrosis. Gustafson T 2007 (6)
# 11 : 24413348 : Effects of smoking, gender and occupational exposure on the risk of severe pulmonary fibrosis: a population-based case-control study. Ekström M 2014 (5)
# 12 : 9571528 : Case-control study of idiopathic pulmonary fibrosis and environmental exposures. Mullen J 1998 (3)
# 13 : 28157473 : Occupational exposure and idiopathic pulmonary fibrosis: a multicentre case-control study in Korea. Koo JW 2017 (0)

# %%
# papers citing seed papers by coverage
df = pd.read_csv('papers_citing_ipf_occupational_dust_case_control_studies.csv')
df.sort_values(by='citations of pmidgrp', ascending=False)
# Out:
#      pubdate  \
# 63      2013
# 43      2011
# 81      2015
# 65      2014
# 99      2016
# 39      2009
# 70      2014
# 56      2012
# 23      2004
# 83      2015
# 98      2016
# 95      2016
# 18      2002
# 5       1998
# 38      2009
# 40      2010
# 11      2000
# 101     2016
# 53      2012
# 12      2000
# 74      2014
# 73      2014
# 47      2012
# 29      2006
# 35      2009
# 60      2013
# 32      2008
# 64      2014
# 61      2013
# 22      2004
# ..       ...
# 13      2000
# 30      2007
# 10      2000
# 9       2000
# 8       2000
# 7       2000
# 6       1999
# 4       1997
# 2       1995
# 28      2006
# 31      2007
# 58      2013
# 48      2012
# 57      2013
# 55      2012
# 54      2012
# 52      2012
# 1       1992
# 50      2012
# 49      2012
# 46      2011
# 33      2008
# 45      2011
# 44      2011
# 42      2011
# 41      2010
# 37      2009
# 36      2009
# 34      2008
# 51      2012
#
#                                                                                                                                                                                                              title  \
# 63                                                                                                                                                                  Epidemiology of idiopathic pulmonary fibrosis.
# 43                                                                                                                              New insights into the pathogenesis and treatment of idiopathic pulmonary fibrosis.
# 81                                                                                                                                            Asbestosis and environmental causes of usual interstitial pneumonia.
# 65                                                                           Effects of smoking, gender and occupational exposure on the risk of severe pulmonary fibrosis: a population-based case-control study.
# 99                                                                                               Idiopathic Pulmonary Fibrosis: A Genetic Disease That Involves Mucociliary Dysfunction of the Peripheral Airways.
# 39                                                                         Cigarette smoking is associated with subclinical parenchymal lung disease: the Multi-Ethnic Study of Atherosclerosis (MESA)-lung study.
# 70                                                                                                                                                    Idiopathic pulmonary fibrosis: early detection and referral.
# 56                                                                                                Newly recognized occupational and environmental causes of chronic terminal airways and parenchymal lung disease.
# 23                                                                                                                             The epidemiology of interstitial lung disease and its association with lung cancer.
# 83                                                                                              Modulation of bleomycin-induced lung fibrosis by pegylated hyaluronidase and dopamine receptor antagonist in mice.
# 98                                              Genome-wide imputation study identifies novel HLA locus for pulmonary fibrosis and potential role for auto-immunity in fibrotic idiopathic interstitial pneumonia.
# 95                                                                                                                  Cigarette Smoke Enhances the Expression of Profibrotic Molecules in Alveolar Epithelial Cells.
# 18                                                                   Nationwide prevalence of sporadic and familial idiopathic pulmonary fibrosis: evidence of founder effect among multiplex families in Finland.
# 5                                                                                                                   In search of a cause of cryptogenic fibrosing alveolitis (CFA): one initiating factor or many?
# 38                                                                                                                                    Determinants of initiation and progression of idiopathic pulmonary fibrosis.
# 40                                                                                                                                              Ecogenomics of respiratory diseases of public health significance.
# 11                                                                                        Adult height and cryptogenic fibrosing alveolitis: a case-control study using the UK general practice research database.
# 101                                                                             A Systematic Review of the Role of Dysfunctional Wound Healing in the Pathogenesis and Treatment of Idiopathic Pulmonary Fibrosis.
# 53                                                                      Clinical characteristics of idiopathic pulmonary fibrosis patients with diabetes mellitus: the national survey in Korea from 2003 to 2007.
# 12                                                                                                                             Review of cryptogenic fibrosing alveolitis, including current treatment guidelines.
# 74                                                                                                                                                                  Genetic susceptibility and pulmonary fibrosis.
# 73                                                                                                Mucin 5B promoter polymorphism is associated with susceptibility to interstitial lung diseases in Chinese males.
# 47                                                                                                                                                                      Smoking and idiopathic pulmonary fibrosis.
# 29                                                                                                                             Incidence and mortality of idiopathic pulmonary fibrosis and sarcoidosis in the UK.
# 35                                                                                                                                                      Pulmonary fibrosis: pathogenesis, etiology and regulation.
# 60                                                                                  Mortality and ionising radiation exposures among workers employed at the Fernald Feed Materials Production Center (1951-1985).
# 32                                                                                                                                                       Antioxidants as potential therapeutics for lung fibrosis.
# 64                                                       Investigating significant health trends in idiopathic pulmonary fibrosis (INSIGHTS-IPF): rationale, aims and design of a nationwide prospective registry.
# 61                                                                                                       Idiopathic pulmonary fibrosis: The current status of its epidemiology, diagnosis, and treatment in China.
# 22                                                                                                           Idiopathic pulmonary fibrosis: current understanding of the pathogenesis and the status of treatment.
# ..                                                                                                                                                                                                             ...
# 13                                                                                                                           A critical role for alveolar macrophages in elicitation of pulmonary immune fibrosis.
# 30                                                                                                                                                                             The Role of PPARs in Lung Fibrosis.
# 10                                                                                                                                               Interferon gamma-1b therapy for cryptogenic fibrosing alveolitis.
# 9                                                                                                                                                                        Interstitial fibrosis and growth factors.
# 8                                                                                                                           Idiopathic pulmonary fibrosis in infants: good prognosis with conservative management.
# 7                                                                                                                                           Adult familial cryptogenic fibrosing alveolitis in the United Kingdom.
# 6                                                                                                             The diagnosis, assessment and treatment of diffuse parenchymal lung disease in adults. Introduction.
# 4    British Thoracic Society study of cryptogenic fibrosing alveolitis: current presentation and initial management. Fibrosing Alveolitis Subcommittee of the Research Committee of the British Thoracic Society.
# 2                                                                                                            Epstein-Barr virus replication within pulmonary epithelial cells in cryptogenic fibrosing alveolitis.
# 28                                                                                                                                                               Interstitial lung disease: progress and problems.
# 31                                                                                                                                            Healthcare provider smoking cessation advice among US worker groups.
# 58                                                                                       Histone modifications are responsible for decreased Fas expression and apoptosis resistance in fibrotic lung fibroblasts.
# 48                                                                                                         Imaging diagnosis of interstitial pneumonia with emphysema (combined pulmonary fibrosis and emphysema).
# 57                                                                                                                                                   Role of microRNAs in lung development and pulmonary diseases.
# 55                                                                                                                                                       Personalized medicine: applying 'omics' to lung fibrosis.
# 54                                                                                                                 Asian Dust Particles Induce TGF-β(1) via Reactive Oxygen Species in Bronchial Epithelial Cells.
# 52         Cytokine-like factor 1 gene expression is enriched in idiopathic pulmonary fibrosis and drives the accumulation of CD4+ T cells in murine lungs: evidence for an antifibrotic role in bleomycin injury.
# 1                                                                 New perspectives on basic mechanisms in lung disease. 1. Lung injury, inflammatory mediators, and fibroblast activation in fibrosing alveolitis.
# 50                                                                                                                                                                   Epigenomics of idiopathic pulmonary fibrosis.
# 49                                                                                                                                                                   Telomerase and idiopathic pulmonary fibrosis.
# 46                                                                                                                               Toxic elements in tobacco and in cigarette smoke: inflammation and sensitization.
# 33                                                                                                                                                                                  Idiopathic pulmonary fibrosis.
# 45                                                                                                                              Evolving genomic approaches to idiopathic pulmonary fibrosis: moving beyond genes.
# 44                                                                                                               Age and sex dimorphisms contribute to the severity of bleomycin-induced lung injury and fibrosis.
# 42                                                                                                                    Vitamin E modulates cigarette smoke extract-induced cell apoptosis in mouse embryonic cells.
# 41                                                                                                                                                      Workshop on idiopathic pulmonary fibrosis in older adults.
# 37                                                                                                                              Pneumoconiosis from agricultural dust exposure among young California farmworkers.
# 36                                                                                                                                   Questionnaire assessment of airway disease symptoms in equine barn personnel.
# 34                                                                                                                                          Hepatitis C virus enhances incidence of idiopathic pulmonary fibrosis.
# 51                                                                     Allele-specific transactivation of matrix metalloproteinase 7 by FOXA2 and correlation with plasma levels in idiopathic pulmonary fibrosis.
#
#           firstauthor         lastauthor                             journal  \
# 63              Ley B         Collard HR                      Clin Epidemiol
# 43             Ding Q      Thannickal VJ                               Drugs
# 81           Gulati M         Redlich CA                  Curr Opin Pulm Med
# 65          Ekström M            Torén K                            BMJ Open
# 99           Evans CM        Schwartz DA                         Physiol Rev
# 39         Lederer DJ            Barr RG           Am J Respir Crit Care Med
# 70          Oldham JM             Noth I                          Respir Med
# 56           Sauler M           Gulati M                      Clin Chest Med
# 23            Raghu G           Morgan G                         Br J Cancer
# 83       Skurikhin EG           Dygai AM                            PLoS One
# 98       Fingerlin TE        Schwartz DA                           BMC Genet
# 95            Checa M           Selman M                            PLoS One
# 18          Hodgson U        Tukiainen P                              Thorax
# 5    Turner-Warwick M   Turner-Warwick M                              Thorax
# 38        Kottmann RM            Sime PJ                         Respirology
# 40     Garantziotis S        Schwartz DA              Annu Rev Public Health
# 11          Hubbard R             Venn A                              Thorax
# 101       Betensley A       Karamichos D                          J Clin Med
# 53             Kim YJ           Jeong SH                    J Korean Med Sci
# 12          Bourke SC           Clague H                      Postgrad Med J
# 74          Mathai SK            Warg LA                  Curr Opin Pulm Med
# 73             Wang C             Wang Y                            PLoS One
# 47              Oh CK         Molfino NA                            Pulm Med
# 29          Gribbin J            Tata LJ                              Thorax
# 35          Wilson MS            Wynn TA                     Mucosal Immunol
# 60          Silver SR           Tseng CY                   Occup Environ Med
# 32             Day BJ             Day BJ               Antioxid Redox Signal
# 64             Behr J          Pittrow D                 BMJ Open Respir Res
# 61            Huang H            Zhong C            Intractable Rare Dis Res
# 22           Khalil N         O'Connor R                                CMAJ
# ..                ...                ...                                 ...
# 13     Zhang-Hoover J  Stein-Streilein J                          Immunology
# 30         Lakatos HF            Sime PJ                            PPAR Res
# 10          Britton J          Britton J                              Thorax
# 9            Lasky JA           Brody AR             Environ Health Perspect
# 8           Hacking D             Heaf D                      Arch Dis Child
# 7         Marshall RP         Laurent GJ                              Thorax
# 6                 NaN                NaN                              Thorax
# 4         Johnston ID            Rudd RM                              Thorax
# 2             Egan JJ        Woodcock AA                              Thorax
# 28          Bourke SJ          Bourke SJ                      Postgrad Med J
# 31             Lee DJ       Clark JD 3rd                         Tob Control
# 58           Huang SK    Peters-Golden M                      Cell Death Dis
# 48            Sakai F         Takemura T                            Pulm Med
# 57            Sessa R             Hata A                           Pulm Circ
# 55     Herazo-Maya JD         Kaminski N                         Biomark Med
# 54           Kyung SY           Jeong SH           Tuberc Respir Dis (Seoul)
# 52            Kass DJ       Greenberg SM                         Am J Pathol
# 1         Sheppard MN        Harrison NK                              Thorax
# 50            Yang IV            Yang IV                         Epigenomics
# 49         Armanios M         Armanios M                           Mutat Res
# 46          Pappas RS          Pappas RS                         Metallomics
# 33         Meltzer EB           Noble PW                 Orphanet J Rare Dis
# 45            Kass DJ         Kaminski N                     Clin Transl Sci
# 44         Redente EF          Riches DW  Am J Physiol Lung Cell Mol Physiol
# 42            Chen ZL              Li JW                      Int J Biol Sci
# 41      Castriotta RJ            High KP                               Chest
# 37        Schenker MB           Green FH             Environ Health Perspect
# 36           Mazan MR         Hoffman AM                    Occup Med (Lond)
# 34            Arase Y           Kumada H               World J Gastroenterol
# 51        Richards TJ            Zhang Y  Am J Physiol Lung Cell Mol Physiol
#
#                                                                                                                                          pubtype  \
# 63                                                                                                                 ['Journal Article', 'Review']
# 43                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 81                                                                                                                 ['Journal Article', 'Review']
# 65                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 99                                                                                                                 ['Journal Article', 'Review']
# 39                                               ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 70                                                                             ['Journal Article', "Research Support, Non-U.S. Gov't", 'Review']
# 56                                                                                                                 ['Journal Article', 'Review']
# 23                                                                                                                 ['Journal Article', 'Review']
# 83                                                                                                                           ['Journal Article']
# 98                                                                                                                           ['Journal Article']
# 95                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 18                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 5                                                                                                                  ['Journal Article', 'Review']
# 38                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 40                                                                                                                 ['Journal Article', 'Review']
# 11                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 101                                                                                                                ['Review', 'Journal Article']
# 53                                                                                                                           ['Journal Article']
# 12                                                                                                                 ['Journal Article', 'Review']
# 74                                                                         ['Journal Article', 'Research Support, N.I.H., Extramural', 'Review']
# 73                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 47                                                                                                                           ['Journal Article']
# 29                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 35                                                                         ['Journal Article', 'Research Support, N.I.H., Intramural', 'Review']
# 60                                       ['Journal Article', "Research Support, U.S. Gov't, Non-P.H.S.", "Research Support, U.S. Gov't, P.H.S."]
# 32                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 64                                                                                                                           ['Journal Article']
# 61                                                                                                                 ['Journal Article', 'Review']
# 22                                                                                                                 ['Journal Article', 'Review']
# ..                                                                                                                                           ...
# 13                                                                                                                           ['Journal Article']
# 30                                                                                                                           ['Journal Article']
# 10                                                                                                                 ['Journal Article', 'Review']
# 9                                                                          ['Journal Article', "Research Support, U.S. Gov't, P.H.S.", 'Review']
# 8                                                                                                                            ['Journal Article']
# 7                                                                                        ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 6                                                                                                                  ['Journal Article', 'Review']
# 4                                                                                        ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 2                                                                                        ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 28                                                                                                                 ['Journal Article', 'Review']
# 31                                               ['Journal Article', "Research Support, Non-U.S. Gov't", "Research Support, U.S. Gov't, P.H.S."]
# 58                                               ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 48                                                                                                                           ['Journal Article']
# 57                                                                                                                 ['Journal Article', 'Review']
# 55                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 54                                                                                                                           ['Journal Article']
# 52                                               ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 1                                                                                                                  ['Journal Article', 'Review']
# 50                                                                                                                 ['Journal Article', 'Review']
# 49                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 46                                                                                                                 ['Journal Article', 'Review']
# 33                                                                                                                 ['Journal Article', 'Review']
# 45                                     ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 44                                               ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 42                                                                                                                           ['Journal Article']
# 41                                                   ['Consensus Development Conference', 'Journal Article', "Research Support, Non-U.S. Gov't"]
# 37   ['Journal Article', "Research Support, Non-U.S. Gov't", "Research Support, U.S. Gov't, Non-P.H.S.", "Research Support, U.S. Gov't, P.H.S."]
# 36                                                                                   ['Journal Article', 'Research Support, N.I.H., Extramural']
# 34                                                                                       ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 51                                               ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
#
#           rcr  citations of pmidgrp
# 63   3.114474                    10
# 43   1.379412                     9
# 81   0.943542                     8
# 65   1.144405                     8
# 99        NaN                     5
# 39   3.310302                     5
# 70   1.139613                     4
# 56   1.008971                     4
# 23   1.747284                     4
# 83   0.272162                     4
# 98        NaN                     4
# 95        NaN                     3
# 18   3.064052                     3
# 5    0.229885                     3
# 38   1.495058                     3
# 40   0.234232                     3
# 11   0.232555                     3
# 101       NaN                     3
# 53   0.383353                     3
# 12   0.110620                     3
# 74   0.843173                     2
# 73   1.541612                     2
# 47   0.596153                     2
# 29   8.027668                     2
# 35   8.678789                     2
# 60   1.755775                     2
# 32   2.769887                     2
# 64   0.708454                     2
# 61   0.082849                     2
# 22   1.637549                     2
# ..        ...                   ...
# 13   0.687025                     1
# 30   0.903618                     1
# 10   0.000000                     1
# 9    1.981621                     1
# 8    0.649444                     1
# 7    3.413365                     1
# 6    0.529739                     1
# 4    4.620485                     1
# 2    3.073204                     1
# 28   0.525774                     1
# 31   0.623457                     1
# 58   2.208995                     1
# 48   0.522390                     1
# 57   2.502042                     1
# 55   0.591325                     1
# 54   0.102769                     1
# 52   0.990963                     1
# 1         NaN                     1
# 50   1.534828                     1
# 49   3.906547                     1
# 46   1.721412                     1
# 33   5.408593                     1
# 45   0.856478                     1
# 44   1.570417                     1
# 42   0.592013                     1
# 41   1.167490                     1
# 37   1.553781                     1
# 36   1.042251                     1
# 34   1.037239                     1
# 51   1.109348                     1
#
# [102 rows x 8 columns]

# %%
# papers citing seed papers by rcr
df = pd.read_csv('papers_citing_ipf_occupational_dust_case_control_studies.csv')
df.sort_values('rcr', ascending=False)
# Out:
#      pubdate  \
# 35      2009
# 29      2006
# 27      2006
# 59      2013
# 89      2015
# 33      2008
# 19      2003
# 72      2014
# 4       1997
# 77      2015
# 49      2012
# 62      2013
# 7       2000
# 39      2009
# 16      2001
# 63      2013
# 2       1995
# 18      2002
# 76      2015
# 32      2008
# 68      2014
# 20      2003
# 57      2013
# 3       1996
# 88      2015
# 58      2013
# 9       2000
# 60      2013
# 23      2004
# 46      2011
# ..       ...
# 66      2014
# 80      2015
# 25      2005
# 53      2012
# 15      2001
# 83      2015
# 69      2014
# 21      2004
# 40      2010
# 11      2000
# 5       1998
# 75      2014
# 12      2000
# 54      2012
# 61      2013
# 10      2000
# 0       1991
# 1       1992
# 90      2016
# 91      2016
# 92      2016
# 93      2016
# 94      2016
# 95      2016
# 96      2016
# 97      2016
# 98      2016
# 99      2016
# 100     2016
# 101     2016
#
#                                                                                                                                                                                                              title  \
# 35                                                                                                                                                      Pulmonary fibrosis: pathogenesis, etiology and regulation.
# 29                                                                                                                             Incidence and mortality of idiopathic pulmonary fibrosis and sarcoidosis in the UK.
# 27                                                                                                                                   Classification and natural history of the idiopathic interstitial pneumonias.
# 59                                                                                                                                                MUC5B promoter polymorphism and interstitial lung abnormalities.
# 89                                                                                                       TOLLIP, MUC5B, and the Response to N-Acetylcysteine among Individuals with Idiopathic Pulmonary Fibrosis.
# 33                                                                                                                                                                                  Idiopathic pulmonary fibrosis.
# 19                                                                                                                                  HLA-DRB1*1101: a significant risk factor for sarcoidosis in blacks and whites.
# 72                                                Association of fine specificity and repertoire expansion of anticitrullinated peptide antibodies with rheumatoid arthritis associated interstitial lung disease.
# 4    British Thoracic Society study of cryptogenic fibrosing alveolitis: current presentation and initial management. Fibrosing Alveolitis Subcommittee of the Research Committee of the British Thoracic Society.
# 77                                                                                                                                                                   Epigenetics of idiopathic pulmonary fibrosis.
# 49                                                                                                                                                                   Telomerase and idiopathic pulmonary fibrosis.
# 62                                                                                                      Interstitial lung abnormalities in a CT lung cancer screening population: prevalence and progression rate.
# 7                                                                                                                                           Adult familial cryptogenic fibrosing alveolitis in the United Kingdom.
# 39                                                                         Cigarette smoking is associated with subclinical parenchymal lung disease: the Multi-Ethnic Study of Atherosclerosis (MESA)-lung study.
# 16                                                                                                                      Adverse effects of oral corticosteroids in relation to dose in patients with lung disease.
# 63                                                                                                                                                                  Epidemiology of idiopathic pulmonary fibrosis.
# 2                                                                                                            Epstein-Barr virus replication within pulmonary epithelial cells in cryptogenic fibrosing alveolitis.
# 18                                                                   Nationwide prevalence of sporadic and familial idiopathic pulmonary fibrosis: evidence of founder effect among multiplex families in Finland.
# 76                                                                                          Plasminogen activator inhibitor 1, fibroblast apoptosis resistance, and aging-related susceptibility to lung fibrosis.
# 32                                                                                                                                                       Antioxidants as potential therapeutics for lung fibrosis.
# 68                                                                                                       Aging mesenchymal stem cells fail to protect because of impaired migration and antiinflammatory response.
# 20                                                                                                                          Pathogenetic mechanisms in usual interstitial pneumonia/idiopathic pulmonary fibrosis.
# 57                                                                                                                                                   Role of microRNAs in lung development and pulmonary diseases.
# 3                                                                                                                                        Mortality rates from cryptogenic fibrosing alveolitis in seven countries.
# 88                                                                                                                                              MicroRNAs as potential targets for progressive pulmonary fibrosis.
# 58                                                                                       Histone modifications are responsible for decreased Fas expression and apoptosis resistance in fibrotic lung fibroblasts.
# 9                                                                                                                                                                        Interstitial fibrosis and growth factors.
# 60                                                                                  Mortality and ionising radiation exposures among workers employed at the Fernald Feed Materials Production Center (1951-1985).
# 23                                                                                                                             The epidemiology of interstitial lung disease and its association with lung cancer.
# 46                                                                                                                               Toxic elements in tobacco and in cigarette smoke: inflammation and sensitization.
# ..                                                                                                                                                                                                             ...
# 66                                                                                                         Genetic susceptibility to interstitial pulmonary fibrosis in mice induced by vanadium pentoxide (V2O5).
# 80                                                                                                                                                                      Smoking-related interstitial lung disease.
# 25                                                                                                         TGF-beta1 and serum both stimulate contraction but differentially affect apoptosis in 3D collagen gels.
# 53                                                                      Clinical characteristics of idiopathic pulmonary fibrosis patients with diabetes mellitus: the national survey in Korea from 2003 to 2007.
# 15                                                                                                                                                             Autoantibodies in cryptogenic fibrosing alveolitis.
# 83                                                                                              Modulation of bleomycin-induced lung fibrosis by pegylated hyaluronidase and dopamine receptor antagonist in mice.
# 69                                                                                                                  A multifactoral analysis of 1452 patients for smoking sensation. An outpatient lab experience.
# 21                                                                 Values of high-resolution computed tomography and pulmonary function tests in managements of patients with chronic hepatitis C virus infection.
# 40                                                                                                                                              Ecogenomics of respiratory diseases of public health significance.
# 11                                                                                        Adult height and cryptogenic fibrosing alveolitis: a case-control study using the UK general practice research database.
# 5                                                                                                                   In search of a cause of cryptogenic fibrosing alveolitis (CFA): one initiating factor or many?
# 75                                                                                                                                      Interstitial lung disease: raising the index of suspicion in primary care.
# 12                                                                                                                             Review of cryptogenic fibrosing alveolitis, including current treatment guidelines.
# 54                                                                                                                 Asian Dust Particles Induce TGF-β(1) via Reactive Oxygen Species in Bronchial Epithelial Cells.
# 61                                                                                                       Idiopathic pulmonary fibrosis: The current status of its epidemiology, diagnosis, and treatment in China.
# 10                                                                                                                                               Interferon gamma-1b therapy for cryptogenic fibrosing alveolitis.
# 0                                                                                                                                               Critical appraisal of published research: introductory guidelines.
# 1                                                                 New perspectives on basic mechanisms in lung disease. 1. Lung injury, inflammatory mediators, and fibroblast activation in fibrosing alveolitis.
# 90                                                                                Current knowledge of US metal and nonmetal miner health: Current and potential data sources for analysis of miner health status.
# 91                                                                                                                                Candidate genes of idiopathic pulmonary fibrosis: current evidence and research.
# 92                                                                                                                                    Association Between Interstitial Lung Abnormalities and All-Cause Mortality.
# 93                                                                                                                                                                        Pulmonary health effects of agriculture.
# 94                                                                                                                                         UK asbestos imports and mortality due to idiopathic pulmonary fibrosis.
# 95                                                                                                                  Cigarette Smoke Enhances the Expression of Profibrotic Molecules in Alveolar Epithelial Cells.
# 96                                                                                                           Efficacy of N-Acetylcysteine in Idiopathic Pulmonary Fibrosis: A Systematic Review and Meta-Analysis.
# 97                                                                                                                                                          Matrix Remodeling in Pulmonary Fibrosis and Emphysema.
# 98                                              Genome-wide imputation study identifies novel HLA locus for pulmonary fibrosis and potential role for auto-immunity in fibrotic idiopathic interstitial pneumonia.
# 99                                                                                               Idiopathic Pulmonary Fibrosis: A Genetic Disease That Involves Mucociliary Dysfunction of the Peripheral Airways.
# 100                                                                                                               Efficacy of antioxidant in idiopathic pulmonary fibrosis: A systematic review and meta-analysis.
# 101                                                                             A Systematic Review of the Role of Dysfunctional Wound Healing in the Pathogenesis and Treatment of Idiopathic Pulmonary Fibrosis.
#
#           firstauthor          lastauthor                    journal  \
# 35          Wilson MS             Wynn TA            Mucosal Immunol
# 29          Gribbin J             Tata LJ                     Thorax
# 27             Kim DS          King TE Jr         Proc Am Thorac Soc
# 59     Hunninghake GM         Schwartz DA               N Engl J Med
# 89          Oldham JM              Noth I  Am J Respir Crit Care Med
# 33         Meltzer EB            Noble PW        Orphanet J Rare Dis
# 19         Rossman MD             Monos D             Am J Hum Genet
# 72           Giles JT           Bathon JM              Ann Rheum Dis
# 4         Johnston ID             Rudd RM                     Thorax
# 77            Yang IV         Schwartz DA                 Transl Res
# 49         Armanios M          Armanios M                  Mutat Res
# 62             Jin GY             Kwon KS                  Radiology
# 7         Marshall RP          Laurent GJ                     Thorax
# 39         Lederer DJ             Barr RG  Am J Respir Crit Care Med
# 16           Walsh LJ     Tattersfield AE                     Thorax
# 63              Ley B          Collard HR             Clin Epidemiol
# 2             Egan JJ         Woodcock AA                     Thorax
# 18          Hodgson U         Tukiainen P                     Thorax
# 76           Huang WT              Liu RM               Exp Gerontol
# 32             Day BJ              Day BJ      Antioxid Redox Signal
# 68          Bustos ML             Rojas M  Am J Respir Crit Care Med
# 20           White ES       Thannickal VJ                   J Pathol
# 57            Sessa R              Hata A                  Pulm Circ
# 3           Hubbard R           Britton J                     Thorax
# 88      Rajasekaran S  Sudhakar Gandhi PS            Front Pharmacol
# 58           Huang SK     Peters-Golden M             Cell Death Dis
# 9            Lasky JA            Brody AR    Environ Health Perspect
# 60          Silver SR            Tseng CY          Occup Environ Med
# 23            Raghu G            Morgan G                Br J Cancer
# 46          Pappas RS           Pappas RS                Metallomics
# ..                ...                 ...                        ...
# 66         Walters DM       Kleeberger SR                    FASEB J
# 80         Hagmeyer L         Randerath W          Dtsch Arztebl Int
# 25        Kobayashi T          Rennard SI                 Respir Res
# 53             Kim YJ            Jeong SH           J Korean Med Sci
# 15            Singh S           du Bois R                 Respir Res
# 83       Skurikhin EG            Dygai AM                   PLoS One
# 69          Tsiouda T      Zarogoulidis K                   J Cancer
# 21           Okutan O             Silit E      World J Gastroenterol
# 40     Garantziotis S         Schwartz DA     Annu Rev Public Health
# 11          Hubbard R              Venn A                     Thorax
# 5    Turner-Warwick M    Turner-Warwick M                     Thorax
# 75          Zibrak JD             Price D   NPJ Prim Care Respir Med
# 12          Bourke SC            Clague H             Postgrad Med J
# 54           Kyung SY            Jeong SH  Tuberc Respir Dis (Seoul)
# 61            Huang H             Zhong C   Intractable Rare Dis Res
# 10          Britton J           Britton J                     Thorax
# 0           Fowkes FG           Fulton PM                        BMJ
# 1         Sheppard MN         Harrison NK                     Thorax
# 90          Yeoman KM            Laney AS  Arch Environ Occup Health
# 91             Zhou W              Wang Y            Appl Clin Genet
# 92          Putman RK      Hunninghake GM                       JAMA
# 93        Nordgren TM           Bailey KL         Curr Opin Pulm Med
# 94          Barber CM          Fishwick D           Occup Med (Lond)
# 95            Checa M            Selman M                   PLoS One
# 96              Sun T           Zhao de W       Medicine (Baltimore)
# 97         Kulkarni T       Thannickal VJ  Am J Respir Cell Mol Biol
# 98       Fingerlin TE         Schwartz DA                  BMC Genet
# 99           Evans CM         Schwartz DA                Physiol Rev
# 100       Kandhare AD        Bodhankar SL                    EXCLI J
# 101       Betensley A        Karamichos D                 J Clin Med
#
#                                                                                                                                      pubtype  \
# 35                                                                     ['Journal Article', 'Research Support, N.I.H., Intramural', 'Review']
# 29                                                                                   ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 27                                                                     ['Journal Article', 'Research Support, N.I.H., Extramural', 'Review']
# 59                                   ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, U.S. Gov't, Non-P.H.S."]
# 89                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 33                                                                                                             ['Journal Article', 'Review']
# 19                                                          ['Journal Article', 'Multicenter Study', "Research Support, U.S. Gov't, P.H.S."]
# 72                                                                               ['Journal Article', 'Research Support, N.I.H., Extramural']
# 4                                                                                    ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 77                         ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, U.S. Gov't, Non-P.H.S.", 'Review']
# 49                                 ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 62            ['Journal Article', 'Randomized Controlled Trial', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 7                                                                                    ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 39                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 16               ['Clinical Trial', 'Comparative Study', 'Controlled Clinical Trial', 'Journal Article', "Research Support, Non-U.S. Gov't"]
# 63                                                                                                             ['Journal Article', 'Review']
# 2                                                                                    ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 18                                                                                   ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 76                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 32                                 ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't", 'Review']
# 68                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 20                                 ['Journal Article', "Research Support, Non-U.S. Gov't", "Research Support, U.S. Gov't, P.H.S.", 'Review']
# 57                                                                                                             ['Journal Article', 'Review']
# 3                                                                                                                        ['Journal Article']
# 88                                                                                                             ['Journal Article', 'Review']
# 58                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 9                                                                      ['Journal Article', "Research Support, U.S. Gov't, P.H.S.", 'Review']
# 60                                   ['Journal Article', "Research Support, U.S. Gov't, Non-P.H.S.", "Research Support, U.S. Gov't, P.H.S."]
# 23                                                                                                             ['Journal Article', 'Review']
# 46                                                                                                             ['Journal Article', 'Review']
# ..                                                                                                                                       ...
# 66                                           ['Journal Article', 'Research Support, N.I.H., Intramural', "Research Support, Non-U.S. Gov't"]
# 80                                                                                                             ['Journal Article', 'Review']
# 25                                           ['Journal Article', 'Research Support, N.I.H., Extramural', "Research Support, Non-U.S. Gov't"]
# 53                                                                                                                       ['Journal Article']
# 15                                                                                                            ['Comment', 'Journal Article']
# 83                                                                                                                       ['Journal Article']
# 69                                                                                                                       ['Journal Article']
# 21                                                                                                                       ['Journal Article']
# 40                                                                                                             ['Journal Article', 'Review']
# 11                                                                                   ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 5                                                                                                              ['Journal Article', 'Review']
# 75                                                                                                             ['Journal Article', 'Review']
# 12                                                                                                             ['Journal Article', 'Review']
# 54                                                                                                                       ['Journal Article']
# 61                                                                                                             ['Journal Article', 'Review']
# 10                                                                                                             ['Journal Article', 'Review']
# 0                                                                                                           ['Guideline', 'Journal Article']
# 1                                                                                                              ['Journal Article', 'Review']
# 90                                                                                                             ['Journal Article', 'Review']
# 91                                                                                                             ['Journal Article', 'Review']
# 92   ['Journal Article', 'Research Support, N.I.H., Extramural', 'Research Support, N.I.H., Intramural', "Research Support, Non-U.S. Gov't"]
# 93                                                                     ['Journal Article', 'Research Support, N.I.H., Extramural', 'Review']
# 94                                                                                   ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 95                                                                                   ['Journal Article', "Research Support, Non-U.S. Gov't"]
# 96                                                                                            ['Journal Article', 'Meta-Analysis', 'Review']
# 97                                                                                                                       ['Journal Article']
# 98                                                                                                                       ['Journal Article']
# 99                                                                                                             ['Journal Article', 'Review']
# 100                                                                                                            ['Review', 'Journal Article']
# 101                                                                                                            ['Review', 'Journal Article']
#
#           rcr  citations of pmidgrp
# 35   8.678789                     2
# 29   8.027668                     2
# 27   5.930767                     1
# 59   5.447068                     1
# 89   5.441405                     1
# 33   5.408593                     1
# 19   5.168552                     1
# 72   5.003475                     1
# 4    4.620485                     1
# 77   3.962266                     1
# 49   3.906547                     1
# 62   3.833627                     1
# 7    3.413365                     1
# 39   3.310302                     5
# 16   3.250437                     1
# 63   3.114474                    10
# 2    3.073204                     1
# 18   3.064052                     3
# 76   3.042723                     1
# 32   2.769887                     2
# 68   2.757979                     1
# 20   2.590888                     2
# 57   2.502042                     1
# 3    2.405705                     2
# 88   2.368967                     1
# 58   2.208995                     1
# 9    1.981621                     1
# 60   1.755775                     2
# 23   1.747284                     4
# 46   1.721412                     1
# ..        ...                   ...
# 66   0.460189                     1
# 80   0.451514                     1
# 25   0.399943                     1
# 53   0.383353                     3
# 15   0.296471                     2
# 83   0.272162                     4
# 69   0.269955                     1
# 21   0.247526                     2
# 40   0.234232                     3
# 11   0.232555                     3
# 5    0.229885                     3
# 75   0.166077                     1
# 12   0.110620                     3
# 54   0.102769                     1
# 61   0.082849                     2
# 10   0.000000                     1
# 0         NaN                     1
# 1         NaN                     1
# 90        NaN                     1
# 91        NaN                     2
# 92        NaN                     1
# 93        NaN                     2
# 94        NaN                     2
# 95        NaN                     3
# 96        NaN                     1
# 97        NaN                     1
# 98        NaN                     4
# 99        NaN                     5
# 100       NaN                     1
# 101       NaN                     3
#
# [102 rows x 8 columns]

# %%
# papers citing seed papers (ipfjes case-control studies) by jaccard index
df = pd.read_csv('ipfjes-case-control-studies.csv')
jt = jaccard_table(df)
jdf = jaccard_tabledf(jt)
jdf
# Out:
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#      citedby  \
# 1   25621562
# 46   8882078
# 40  11009575
# 0   26285574
# 2   25121989
# 43  10943637
# 42  10992540
# 39  11083888
# 47   8553293
# 41  11006787
# 44  10906025
# 45  10193340
# 49   1494772
# 31  24348069
# 32  23322915
# 34  21668038
# 35  19740254
# 36  19542480
# 37  14760762
# 38  11923553
# 3   24847384
# 48   2043787
# 33  22787370
# 30  24413348
# 26  26443305
# 27  25984423
# 28  25621562
# 29  25478169
# 25  28035951
#
#                                                                                                                                                         title  \
# 1                                                                                        Asbestosis and environmental causes of usual interstitial pneumonia.
# 46                                                                                  Mortality rates from cryptogenic fibrosing alveolitis in seven countries.
# 40                                                                        Review of cryptogenic fibrosing alveolitis, including current treatment guidelines.
# 0                                             Re-evaluation of diagnostic parameters is crucial for obtaining accurate data on idiopathic pulmonary fibrosis.
# 2                                            Mucin 5B promoter polymorphism is associated with susceptibility to interstitial lung diseases in Chinese males.
# 43                                                                                          Interferon gamma-1b therapy for cryptogenic fibrosing alveolitis.
# 42                                   Adult height and cryptogenic fibrosing alveolitis: a case-control study using the UK general practice research database.
# 39                                                                                               Capsaicin induced cough in cryptogenic fibrosing alveolitis.
# 47                                                      Epstein-Barr virus replication within pulmonary epithelial cells in cryptogenic fibrosing alveolitis.
# 41                                                       The diagnosis, assessment and treatment of diffuse parenchymal lung disease in adults. Introduction.
# 44                                                                     Idiopathic pulmonary fibrosis in infants: good prognosis with conservative management.
# 45                                                             In search of a cause of cryptogenic fibrosing alveolitis (CFA): one initiating factor or many?
# 49           New perspectives on basic mechanisms in lung disease. 1. Lung injury, inflammatory mediators, and fibroblast activation in fibrosing alveolitis.
# 31                                                                                                             Epidemiology of idiopathic pulmonary fibrosis.
# 32                             Mortality and ionising radiation exposures among workers employed at the Fernald Feed Materials Production Center (1951-1985).
# 34                                                                         New insights into the pathogenesis and treatment of idiopathic pulmonary fibrosis.
# 35                                                                               Determinants of initiation and progression of idiopathic pulmonary fibrosis.
# 36                    Cigarette smoking is associated with subclinical parenchymal lung disease: the Multi-Ethnic Study of Atherosclerosis (MESA)-lung study.
# 37            Values of high-resolution computed tomography and pulmonary function tests in managements of patients with chronic hepatitis C virus infection.
# 38              Nationwide prevalence of sporadic and familial idiopathic pulmonary fibrosis: evidence of founder effect among multiplex families in Finland.
# 3                                                              A multifactoral analysis of 1452 patients for smoking sensation. An outpatient lab experience.
# 48                                                                                         Critical appraisal of published research: introductory guidelines.
# 33                 Clinical characteristics of idiopathic pulmonary fibrosis patients with diabetes mellitus: the national survey in Korea from 2003 to 2007.
# 30                      Effects of smoking, gender and occupational exposure on the risk of severe pulmonary fibrosis: a population-based case-control study.
# 26                                                                            Clinical features of rheumatoid arthritis-associated interstitial lung disease.
# 27                                                                                                Diagnosis of idiopathic pulmonary fibrosis: Current issues.
# 28                                                                                       Asbestosis and environmental causes of usual interstitial pneumonia.
# 29  Investigating significant health trends in idiopathic pulmonary fibrosis (INSIGHTS-IPF): rationale, aims and design of a nationwide prospective registry.
# 25                         A Systematic Review of the Role of Dysfunctional Wound Healing in the Pathogenesis and Treatment of Idiopathic Pulmonary Fibrosis.
#
#          firstauthor        lastauthor                    journal  \
# 1           Gulati M        Redlich CA         Curr Opin Pulm Med
# 46         Hubbard R         Britton J                     Thorax
# 40         Bourke SC          Clague H             Postgrad Med J
# 0         Kaunisto J     Myllärniemi M               BMC Pulm Med
# 2             Wang C            Wang Y                   PLoS One
# 43         Britton J         Britton J                     Thorax
# 42         Hubbard R            Venn A                     Thorax
# 39        Doherty MJ      Calverley PM                     Thorax
# 47           Egan JJ       Woodcock AA                     Thorax
# 41                                                         Thorax
# 44         Hacking D            Heaf D             Arch Dis Child
# 45  Turner-Warwick M  Turner-Warwick M                     Thorax
# 49       Sheppard MN       Harrison NK                     Thorax
# 31             Ley B        Collard HR             Clin Epidemiol
# 32         Silver SR          Tseng CY          Occup Environ Med
# 34            Ding Q     Thannickal VJ                      Drugs
# 35       Kottmann RM           Sime PJ                Respirology
# 36        Lederer DJ           Barr RG  Am J Respir Crit Care Med
# 37          Okutan O           Silit E      World J Gastroenterol
# 38         Hodgson U       Tukiainen P                     Thorax
# 3          Tsiouda T    Zarogoulidis K                   J Cancer
# 48         Fowkes FG         Fulton PM                        BMJ
# 33            Kim YJ          Jeong SH           J Korean Med Sci
# 30         Ekström M           Torén K                   BMJ Open
# 26            Wang T          Liang ZA                    Sci Rep
# 27          Prasad R           Gupta P   Intractable Rare Dis Res
# 28          Gulati M        Redlich CA         Curr Opin Pulm Med
# 29            Behr J         Pittrow D        BMJ Open Respir Res
# 25       Betensley A      Karamichos D                 J Clin Med
#
#              pubdate  \
# 1   2015/03/01 00:00
# 46  1996/07/01 00:00
# 40  2000/10/01 00:00
# 0   2015/08/19 00:00
# 2   2014/08/14 00:00
# 43  2000/08/01 00:00
# 42  2000/10/01 00:00
# 39  2000/12/01 00:00
# 47  1995/12/01 00:00
# 41  1999/04/01 00:00
# 44  2000/08/01 00:00
# 45  1998/08/01 00:00
# 49  1992/12/01 00:00
# 31  2013/11/25 00:00
# 32  2013/07/01 00:00
# 34  2011/05/28 00:00
# 35  2009/09/01 00:00
# 36  2009/09/01 00:00
# 37  2004/02/01 00:00
# 38  2002/04/01 00:00
# 3   2014/05/10 00:00
# 48  1991/05/11 00:00
# 33  2012/07/01 00:00
# 30  2014/01/09 00:00
# 26  2015/10/07 00:00
# 27  2015/05/01 00:00
# 28  2015/03/01 00:00
# 29  2014/01/03 00:00
# 25  2016/12/26 00:00
#
#                                                                                               pubtype  \
# 1                                                                           [Journal Article, Review]
# 46                                                                                  [Journal Article]
# 40                                                                          [Journal Article, Review]
# 0                              [Journal Article, Multicenter Study, Research Support, Non-U.S. Gov't]
# 2                                                 [Journal Article, Research Support, Non-U.S. Gov't]
# 43                                                                          [Journal Article, Review]
# 42                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 39                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 47                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 41                                                                          [Journal Article, Review]
# 44                                                                                  [Journal Article]
# 45                                                                          [Journal Article, Review]
# 49                                                                          [Journal Article, Review]
# 31                                                                          [Journal Article, Review]
# 32  [Journal Article, Research Support, U.S. Gov't, Non-P.H.S., Research Support, U.S. Gov't, P.H.S.]
# 34  [Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't, Review]
# 35  [Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't, Review]
# 36          [Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't]
# 37                                                                                  [Journal Article]
# 38                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 3                                                                                   [Journal Article]
# 48                                                                       [Guideline, Journal Article]
# 33                                                                                  [Journal Article]
# 30                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 26                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 27                                                                          [Journal Article, Review]
# 28                                                                          [Journal Article, Review]
# 29                                                                                  [Journal Article]
# 25                                                                          [Review, Journal Article]
#
#          rcr   jaccard
# 1   1.000536  0.134328
# 46  2.408935  0.125000
# 40  0.111113  0.076923
# 0   1.167218  0.071429
# 2   1.625522  0.063492
# 43  0.037982  0.041667
# 42  0.254402  0.037037
# 39  1.353383  0.032258
# 47  3.089159  0.026316
# 41  0.734127  0.026201
# 44  0.636489  0.022727
# 45  0.225965  0.021739
# 49       NaN  0.016129
# 31  3.932975  0.011765
# 32  1.500012  0.000000
# 34  1.402458  0.000000
# 35  1.487796  0.000000
# 36  3.349219  0.000000
# 37  0.241114  0.000000
# 38  3.140189  0.000000
# 3   0.216957  0.000000
# 48       NaN  0.000000
# 33  0.433436  0.000000
# 30  1.350940  0.000000
# 26  0.726112  0.000000
# 27  1.474051  0.000000
# 28  1.000536  0.000000
# 29  0.871415  0.000000
# 25       NaN  0.000000

# %%
# papers citing seed papers (ipfjes reviews) by jaccard index

df = pd.read_csv('ipfjes-review-articles.csv')
jt = jaccard_table(df)
jdf = jaccard_tabledf(jt)
jdf
# Out:
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/pandas/core/generic.py:2773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value
# /home/drcjar/.virtualenvs/litsearch/lib/python3.5/site-packages/pandas/core/indexing.py:141: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
#      citedby  \
# 35  26841042
# 43  26400796
# 39  26595739
# 47  25121989
# 26  28035951
# 42  26511746
# 37  26732054
# 25  28145905
# 45  26176965
# 40  26594173
# 32  27023440
# 38  26637194
# 28  27899769
# 52  11290559
# 50  19014649
# 41  26523279
# 33  26993524
# 49  24972672
# 44  26400687
# 30  27461264
# 29  27657144
# 46  25244922
# 48  25061279
# 51  15113854
# 0   27856478
# 36  26738569
# 27  27913421
# 31  27335371
# 34  26978351
#
#                                                                                                                                                                                                                 title  \
# 35                                                                                                                                                   Epidemiology of Idiopathic Pulmonary Fibrosis in Northern Italy.
# 43                                                                                                                     Incorporating genetics into the identification and treatment of Idiopathic Pulmonary Fibrosis.
# 39                                                                                                                                                                           MUC5B and Idiopathic Pulmonary Fibrosis.
# 47                                                                                                   Mucin 5B promoter polymorphism is associated with susceptibility to interstitial lung diseases in Chinese males.
# 26                                                                                 A Systematic Review of the Role of Dysfunctional Wound Healing in the Pathogenesis and Treatment of Idiopathic Pulmonary Fibrosis.
# 42                                                                                                                                            UK asbestos imports and mortality due to idiopathic pulmonary fibrosis.
# 37                                                                                                                       Clinical and economic burden of idiopathic pulmonary fibrosis: a retrospective cohort study.
# 25                                                                                                                                          Mitochondria in the spotlight of aging and idiopathic pulmonary fibrosis.
# 45                                                                                                                                          Epigenetics in lung fibrosis: from pathobiology to treatment perspective.
# 40                                                                                                                                                 MicroRNAs as potential targets for progressive pulmonary fibrosis.
# 32                                                                                                                               Impact of Comorbidities on Mortality in Patients with Idiopathic Pulmonary Fibrosis.
# 38                                                                                           The care needs of patients with idiopathic pulmonary fibrosis and their carers (CaNoPy): results of a qualitative study.
# 28                                                                                                                              The role of club cell phenoconversion and migration in idiopathic pulmonary fibrosis.
# 52  Cyclooxygenase-2 deficiency results in a loss of the anti-proliferative response to transforming growth factor-beta in human fibrotic lung fibroblasts and promotes bleomycin-induced pulmonary fibrosis in mice.
# 50                                                                                                                                         Viruses as co-factors for the initiation or exacerbation of lung fibrosis.
# 41                                      Breakdown of Epithelial Barrier Integrity and Overdrive Activation of Alveolar Epithelial Cells in the Pathogenesis of Acute Respiratory Distress Syndrome and Lung Fibrosis.
# 33                                                                        Elevated expression of NEU1 sialidase in idiopathic pulmonary fibrosis provokes pulmonary collagen deposition, lymphocytosis, and fibrosis.
# 49                                                                               An autopsy study of combined pulmonary fibrosis and emphysema: correlations among clinical, radiological, and pathological features.
# 44                                                                                                     Why do patients get idiopathic pulmonary fibrosis? Current concepts in the pathogenesis of pulmonary fibrosis.
# 30                                                                                             Variable course of disease of rheumatoid arthritis-associated usual interstitial pneumonia compared to other subtypes.
# 29                                                                                                                   Advanced Therapeutic Strategies for Chronic Lung Disease Using Nanoparticle-Based Drug Delivery.
# 46                                                                                                                                        Telomere-regulating genes and the telomere interactome in familial cancers.
# 48                                                                                                       Treatment of pulmonary hypertension in idiopathic pulmonary fibrosis: shortfall in efficacy or trial design?
# 51                                                                                                               Augmented pulmonary IL-4 and IL-13 receptor subunit expression in idiopathic interstitial pneumonia.
# 0                                                            Prognostic factors of idiopathic inflammatory myopathies complicated with interstitial lung disease: protocol for a systematic review and meta-analysis.
# 36                                                                                                             TGF-β1 Upregulates the Expression of Triggering Receptor Expressed on Myeloid Cells 1 in Murine Lungs.
# 27                                                                                                                                                            Role of IL-17A in murine models of COPD airway disease.
# 31                                                                                                         Wnt/β-catenin pathway in tissue injury: roles in pathology and therapeutic opportunities for regeneration.
# 34                                                                                                                                         Crosstalk between Long Noncoding RNAs and MicroRNAs in Health and Disease.
#
#            firstauthor          lastauthor  \
# 35            Harari S            Cesana G
# 43           Mathai SK         Schwartz DA
# 39             Yang IV         Schwartz DA
# 47              Wang C              Wang Y
# 26         Betensley A        Karamichos D
# 42           Barber CM          Fishwick D
# 37          Raimundo K          Swigris JJ
# 25             Mora AL             Rojas M
# 45          Helling BA             Yang IV
# 40       Rajasekaran S  Sudhakar Gandhi PS
# 32           Kreuter M            Herth FJ
# 38           Sampson C             Byrne A
# 28          Fukumoto J         Kolliputi N
# 52    Keerthisingam CB         McAnulty RJ
# 50         Vannella KM            Moore BB
# 41            Yanagi S          Nakazato M
# 33           Luzina IG           Atamas SP
# 49           Inomata M          Takemura T
# 44          Bellaye PS              Kolb M
# 30            Nurmi HM      Kaarteenaho RL
# 29             Yhee JY              Nho RS
# 46  Robles-Espinoza CD            Adams DJ
# 48           Nathan SD             King CS
# 51         Jakubzick C         Hogaboam CM
# 0             Kamiya H              Sozu T
# 36              Peng L             Guan CX
# 27        Yanagisawa H        Nishimura SL
# 31         Bastakoty D            Young PP
# 34          Bayoumi AS              Kim IM
#
#                                journal           pubdate  \
# 35                            PLoS One  2016/02/03 00:00
# 43                             BMC Med  2015/09/24 00:00
# 39                   Ann Am Thorac Soc  2015/11/01 00:00
# 47                            PLoS One  2014/08/14 00:00
# 26                          J Clin Med  2016/12/26 00:00
# 42                    Occup Med (Lond)  2016/03/01 00:00
# 37                        BMC Pulm Med  2016/01/05 00:00
# 25                       J Clin Invest  2017/02/01 00:00
# 45                  Curr Opin Pulm Med  2015/09/01 00:00
# 40                     Front Pharmacol  2015/11/05 00:00
# 32                            PLoS One  2016/03/29 00:00
# 38                        BMC Pulm Med  2015/12/04 00:00
# 28                   Aging (Albany NY)  2016/11/29 00:00
# 52                         Am J Pathol  2001/04/01 00:00
# 50          Fibrogenesis Tissue Repair  2008/10/13 00:00
# 41                      Biomed Res Int  2015/01/01 00:00
# 33  Am J Physiol Lung Cell Mol Physiol  2016/05/15 00:00
# 49                        BMC Pulm Med  2014/06/28 00:00
# 44                             BMC Med  2015/09/24 00:00
# 30                        BMC Pulm Med  2016/07/27 00:00
# 29                          J Clin Med  2016/09/20 00:00
# 46                      Mol Cancer Res  2015/02/01 00:00
# 48                 Drug Des Devel Ther  2014/07/02 00:00
# 51                       J Clin Pathol  2004/05/01 00:00
# 0                             BMJ Open  2016/11/17 00:00
# 36                             Sci Rep  2016/01/07 00:00
# 27  Am J Physiol Lung Cell Mol Physiol  2017/01/01 00:00
# 31                             FASEB J  2016/10/01 00:00
# 34                       Int J Mol Sci  2016/03/11 00:00
#
#                                                                                               pubtype  \
# 35                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 43                                                                                  [Journal Article]
# 39                                                                                  [Journal Article]
# 47                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 26                                                                          [Review, Journal Article]
# 42                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 37                                                                                  [Journal Article]
# 25                                                                          [Journal Article, Review]
# 45                                    [Journal Article, Research Support, N.I.H., Extramural, Review]
# 40                                                                          [Journal Article, Review]
# 32                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 38                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 28                                                                                  [Journal Article]
# 52                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 50                                                                                  [Journal Article]
# 41                                        [Journal Article, Research Support, Non-U.S. Gov't, Review]
# 33                                                                                  [Journal Article]
# 49                                                                                  [Journal Article]
# 44                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 30                                                                                  [Journal Article]
# 29                                                                          [Journal Article, Review]
# 46                                        [Journal Article, Research Support, Non-U.S. Gov't, Review]
# 48                                        [Journal Article, Research Support, Non-U.S. Gov't, Review]
# 51                                                                                  [Journal Article]
# 0                                                                                   [Journal Article]
# 36                                                [Journal Article, Research Support, Non-U.S. Gov't]
# 27                                                                                  [Journal Article]
# 31                                                                          [Review, Journal Article]
# 34  [Journal Article, Research Support, N.I.H., Extramural, Research Support, Non-U.S. Gov't, Review]
#
#          rcr   jaccard
# 35       NaN  0.144444
# 43  0.509891  0.136364
# 39  0.981027  0.132812
# 47  1.625522  0.090909
# 26       NaN  0.086420
# 42       NaN  0.065217
# 37       NaN  0.063830
# 25       NaN  0.063348
# 45  1.113041  0.051546
# 40  2.434064  0.047368
# 32       NaN  0.045045
# 38  1.390314  0.043011
# 28       NaN  0.029703
# 52  4.144846  0.021978
# 50  1.736946  0.016529
# 41  0.592057  0.012500
# 33       NaN  0.012346
# 49  1.708922  0.010204
# 44  0.847136  0.010101
# 30       NaN  0.008929
# 29       NaN  0.005525
# 46  1.000300  0.000000
# 48  1.089806  0.000000
# 51  0.890258  0.000000
# 0        NaN  0.000000
# 36       NaN  0.000000
# 27       NaN  0.000000
# 31       NaN  0.000000
# 34       NaN  0.000000

# %%
# next up: describe range/av/etc for rcr, ji, and coverage
# refactor
# command line action?
# check we don't download things we've already downloaded
# make as flask app?
# try bokeh
# add support for http://cbdm-01.zdv.uni-mainz.de/~jfontain/cms/?page_id=253
# do our own machine learning to identify new relevant papers

# %%
# collects a few papers from 2017 which we arbitarily set as our test data

def chunked_pmids_2(chunksize=50):
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    count_handle = Entrez.esearch(db="pubmed",
                                  sort="relevance",
                                  retmode="xml",
                                  rettype="count",
                                  field="DP",
                                  term="2017")
    count_results = Entrez.read(count_handle)
    count = int(count_results["Count"])
    
    retmax_requests = list(range(chunksize, count, chunksize))
        
    retmax_requests.append(count - retmax_requests[len(retmax_requests) - 1]) 
    
    retmax_requests = retmax_requests[-10:] # let's not actually do all the chunks just now
    
    for i, retmax in enumerate(retmax_requests):
        pmid_handle = Entrez.esearch(db="pubmed",
                                     sort="relevance",
                                     retmode="xml",
                                     usehistory='y',
                                     retstart=retmax,
                                     retmax=chunksize,
                                     field="DP",
                                     term="2017")
        results = Entrez.read(pmid_handle)
        yield results["IdList"]
        

# collects a few more papers from 2017 which we arbitarily set as our background data

def chunked_pmids_3(chunksize=1000):
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    count_handle = Entrez.esearch(db="pubmed",
                                  sort="relevance",
                                  retmode="xml",
                                  rettype="count",
                                  field="DP",
                                  term="2017")
    count_results = Entrez.read(count_handle)
    count = int(count_results["Count"])
    
    retmax_requests = list(range(chunksize, count, chunksize))
        
    retmax_requests.append(count - retmax_requests[len(retmax_requests) - 1]) 
    
    # retmax_requests = retmax_requests[-8:] # let's not actually do all the chunks just now
    
    for i, retmax in enumerate(retmax_requests):
        pmid_handle = Entrez.esearch(db="pubmed",
                                     sort="relevance",
                                     retmode="xml",
                                     usehistory='y',
                                     retstart=retmax,
                                     retmax=chunksize,
                                     field="DP",
                                     term="2017")
        results = Entrez.read(pmid_handle)
        yield results["IdList"]

# %%
training_pmid = ["28539779",  "24331795", "22190367", "19878630", "8512477", "27112687"] # eye inflammation pmids - here our test data
test_pmid = list(chunked_pmids_2())

# %%
import os
os.environ['http_proxy']=''

# %%
background_pmid = list(chunked_pmids_3())

# %%
flat_test_pmid = [item for sublist in test_pmid for item in sublist]
flat_background_pmid =[item for sublist in background_pmid for item in sublist]

# %%
litfetch_topic("target", training_pmid)
litfetch_topic("test", flat_test_pmid)
litfetch_topic("background", flat_background_pmid)
# Out:
# begining topic target analaysis
# csv of topic target saved
# begining topic test analaysis
# csv of topic test saved
# begining topic background analaysis
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-0a7ec764668f> in <module>()
#       1 litfetch_topic("target", training_pmid)
#       2 litfetch_topic("test", flat_test_pmid)
# ----> 3 litfetch_topic("background", flat_background_pmid)
#
# <ipython-input-22-638c3e6c9271> in litfetch_topic(topic, pmids)
#      10     """
#      11     print('begining topic {0} analaysis'.format(topic))
# ---> 12     result = lit_fetch(pmids)
#      13     df = resultdf(result)
#      14     save_df_as_csv(topic, df)
#
# <ipython-input-13-43259aa673c6> in lit_fetch(pubmed_id)
#       4     """
#       5     result = {}
# ----> 6     result['summaries'] = get_pubmed_summaries(pubmed_id)
#       7     result['pubtypes'] = get_pubmed_pubtypes(pubmed_id)
#       8     result['abstracts'] = get_pubmed_abstracts(pubmed_id)
#
# <ipython-input-4-54068bcc9440> in get_pubmed_summaries(pubmed_id)
#      10                              retmode='json',
#      11                              rettype='abstract')
# ---> 12     return json.loads(handle.read())['result']
#      13
#
# KeyError: 'result'

# %% [markdown]
# ## machining the learns messing begins

# %%
targetdf = pd.DataFrame.from_csv("target.csv")
testdf = pd.DataFrame.from_csv("test.csv")
backgrounddf = pd.DataFrame.from_csv("background.csv")

# %%
targetdf.abstract[0]

# %%
targetdf['target'] = 1
backgrounddf['target'] = 0
combineddf = pd.concat([targetdf, backgrounddf])

# %%
# http://scikit-learn.org/stable/tutorial/text_analytics/working_with_text_data.html
# http://zacstewart.com/2015/04/28/document-classification-with-scikit-learn.html

from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer()
counts = count_vectorizer.fit_transform(combineddf['abstract'].values)

from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
targets = combineddf['target'].values
classifier.fit(counts, targets)

test_counts = count_vectorizer.transform(testdf['abstract'].values)
predictions = classifier.predict(test_counts)
predictions # [1, 0]

# %%
from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
targets = combineddf['target'].values
classifier.fit(counts, targets)

# %%
test_counts = count_vectorizer.transform(testdf['abstract'].values)
predictions = classifier.predict(test_counts)
predictions # [1, 0]

# %%
combineddf.head()

# %%
def chunked_pmids(term, chunksize=1000):
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    count_handle = Entrez.esearch(db="pubmed",
                                  sort="relevance",
                                  retmode="xml",
                                  rettype="count",
                                  field="DP",
                                  term=term)
    count_results = Entrez.read(count_handle)
    count = int(count_results["Count"])
    
    print(count)
    
    retmax_requests = list(range(0, count, chunksize))
            
    # retmax_requests = retmax_requests[-2:] # let's not actually do all the chunks just now
    
    results = []
    
    for i, retmax in enumerate(retmax_requests):
        print (i)
        print (retmax)
        pmid_handle = Entrez.esearch(db="pubmed",
                                     sort="relevance",
                                     retmode="xml",
                                     usehistory='y',
                                     retstart=retmax,
                                     retmax=chunksize,
                                     field="DP",
                                     term=term)
        results.append(Entrez.read(pmid_handle)["IdList"])
        
    return results

# %%
results = chunked_pmids('1900')

# %%
def fetch_medline(pubmed_id):
    Entrez.email = "carl.reynolds@imperial.ac.uk"
    handle = Entrez.efetch(db='pubmed',
                           id=pubmed_id,
                           rettype='medline',
                           retmode='text')
    records = Medline.parse(handle)
    return records

# %%
# flatresults = [item for sublist in results for item in sublist]

# %%
temp_records = fetch_medline(results[0])

# %%
records = []
db = {}

for record in temp_records:
    records.append(record)

# %%
for record in records:
    db[record.get('PMID')] = record

# %%
db['28549338']['AB']
