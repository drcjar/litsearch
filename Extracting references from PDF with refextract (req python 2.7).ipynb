# %%
from refextract import extract_references_from_file

# %%
reference = extract_references_from_file("pdf/Awadalla2012.pdf")
# Out:
# * /usr/bin/pdftotext -raw -q -enc UTF-8 pdf/Awadalla2012.pdf -
# * convert_PDF_to_plaintext found: 861 lines of text
# * title u'References\n'
# * marker u'1.'
# * title_marker_same_line False
# * references separator \s*(?P<mark>(?P<marknum>\d+)\s*\.(?!\d))
# Loading kb from /home/drcjar/.virtualenvs/ipfaes2.7/local/lib/python2.7/site-packages/refextract/references/kbs/journal-titles.kb
# Processing journals kb
# Processed journals kb
# Loading reports kb from /home/drcjar/.virtualenvs/ipfaes2.7/local/lib/python2.7/site-packages/refextract/references/kbs/report-numbers.kb
# Loaded reports kb
# Loading books kb from /home/drcjar/.virtualenvs/ipfaes2.7/local/lib/python2.7/site-packages/refextract/references/kbs/books.kb
# Loaded books kb
# Loading kb from /home/drcjar/.virtualenvs/ipfaes2.7/local/lib/python2.7/site-packages/refextract/references/kbs/publishers.kb
# ...

# %%
[paper['misc'] for paper in reference['references']]
# Out:
# [[u'Tsoutsou PG, Gourgoulianis KI',
#   u'Cytokine levels in the sera of patients with idiopathic pulmonary fibrosis. Respiratory Medicine 2006'],
#  [u'100:938-45'],
#  [u'Taskar VS, Coultas DB. Is Idiopathic Pulmonary Fibrosis an Environmental Disease? Proc Am Thorac Soc 2006'],
#  [u'3:293-8'],
#  [u'Baumgartner KB, Samet JM, Coultas',
#   u'Occupational and Environmental Risk Factors for Idiopathic Pulmonary Fibrosis: A Multicenter CaseControl',
#   u'Study. Am J Epidemiol',
#   u'2000'],
#  [u'152:307-15'],
#  [u'American Thoracic Society. Idiopathic pulmonary fibrosis: diagnosis and treatment. International consensus statement. American Thoracic Society (ATS), and the European Respiratory Society (ERS). Am',
#   u'2000'],
#  [u'161:646-64'],
#  [u'American Thoracic Society/European Respiratory Society International Multidisciplinary Consensus Classification of the Idiopathic Interstitial Pneumonias. AmJ Respir Crit',
#   u'2002'],
#  [u'165: 277-304'],
#  [u'Figueroa MCG',
# ...
