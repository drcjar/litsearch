# %%
import pandas as pd
import sqlite3
from IPython.display import HTML
# %matplotlib inline

# %%
def make_clickable(val):
    return '<a href="{}">{}</a>'.format(val,val)

# %%
conn = sqlite3.connect('papers.db')
test = pd.read_sql_query('SELECT * FROM papers', conn)

# %%
target = pd.read_csv('ipfjes-case-control-studies.csv', usecols=['pmid','title','firstauthor','lastauthor',
                                                             'journal','pubdate','pubtype',
                                                             'abstract', 'keywords', 'rcr', 'citedby', 'cites'])

# %%
target['target'] = 1

test['target'] = 0

training = pd.concat([target, test.head(14)])

from sklearn.feature_extraction.text import CountVectorizer
count_vectorizer = CountVectorizer()
counts = count_vectorizer.fit_transform(training['abstract'].values)

from sklearn.naive_bayes import MultinomialNB
classifier = MultinomialNB()
targets = training['target'].values
classifier.fit(counts, targets)

test_counts = count_vectorizer.transform(test['abstract'].values)
predictions = classifier.predict(test_counts)
predictions_prob = classifier.predict_proba(test_counts)

# %%
test['testresult'] = predictions
test['testprob'] = pd.DataFrame(predictions_prob)[1]
test['link'] = 'https://www.ncbi.nlm.nih.gov/pubmed/' + test['pmid']

# %%
results = test[(test.testresult == 1) & (test.date.str.contains('2017'))].sort_values(by='testprob', ascending=False)
results[['title', 'link']].style.format(make_clickable) # clickable results are important
# Out:
#         <style  type="text/css" >
#
#
#         </style>
#
#         <table id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7" None>
#
#
#         <thead>
#
#             <tr>
#
#
#                 <th class="blank level0" >
#
#
#
#
#                 <th class="col_heading level0 col0" colspan=1>
#                   title
#
#
#
#                 <th class="col_heading level0 col1" colspan=1>
#                   link
#
#
#             </tr>
#
#         </thead>
#         <tbody>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row0" rowspan=1>
#                     1510
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row0_col0"
#                  class="data row0 col0" >
#                     <a href="Diffuse Pulmonary Ossification in Fibrosing Interstitial Lung Diseases: Prevalence and Associations.">Diffuse Pulmonary Ossification in Fibrosing Interstitial Lung Diseases: Prevalence and Associations.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row0_col1"
#                  class="data row0 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/28182861">https://www.ncbi.nlm.nih.gov/pubmed/28182861</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row1" rowspan=1>
#                     4560
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row1_col0"
#                  class="data row1 col0" >
#                     <a href="The diagnostic importance of the bronchoalveolar lavage in lymphocytic alveolitis.">The diagnostic importance of the bronchoalveolar lavage in lymphocytic alveolitis.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row1_col1"
#                  class="data row1 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/27471881">https://www.ncbi.nlm.nih.gov/pubmed/27471881</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row2" rowspan=1>
#                     3244
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row2_col0"
#                  class="data row2 col0" >
#                     <a href="Cholesterol, lipoproteins and subclinical interstitial lung disease: the MESA study.">Cholesterol, lipoproteins and subclinical interstitial lung disease: the MESA study.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row2_col1"
#                  class="data row2 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/28130491">https://www.ncbi.nlm.nih.gov/pubmed/28130491</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row3" rowspan=1>
#                     86
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row3_col0"
#                  class="data row3 col0" >
#                     <a href="Effect of statins on disease-related outcomes in patients with idiopathic pulmonary fibrosis.">Effect of statins on disease-related outcomes in patients with idiopathic pulmonary fibrosis.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row3_col1"
#                  class="data row3 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/27708114">https://www.ncbi.nlm.nih.gov/pubmed/27708114</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row4" rowspan=1>
#                     99
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row4_col0"
#                  class="data row4 col0" >
#                     <a href="Investigation of viral infection in idiopathic pulmonary fibrosis among Iranian patients in Tehran.">Investigation of viral infection in idiopathic pulmonary fibrosis among Iranian patients in Tehran.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row4_col1"
#                  class="data row4 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/28115263">https://www.ncbi.nlm.nih.gov/pubmed/28115263</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row5" rowspan=1>
#                     3426
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row5_col0"
#                  class="data row5 col0" >
#                     <a href="Histologist's original opinion compared with multidisciplinary team in determining diagnosis in interstitial lung disease.">Histologist's original opinion compared with multidisciplinary team in determining diagnosis in interstitial lung disease.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row5_col1"
#                  class="data row5 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/27815523">https://www.ncbi.nlm.nih.gov/pubmed/27815523</a>
#
#
#             </tr>
#
#             <tr>
#
#
#                 <th id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7"
#                  class="row_heading level0 row6" rowspan=1>
#                     3025
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row6_col0"
#                  class="data row6 col0" >
#                     <a href="Interstitial Lung Disease in the Elderly.">Interstitial Lung Disease in the Elderly.</a>
#
#
#
#                 <td id="T_f8139b8a_6b0b_11e7_a3e6_c4346b5433b7row6_col1"
#                  class="data row6 col1" >
#                     <a href="https://www.ncbi.nlm.nih.gov/pubmed/27865876">https://www.ncbi.nlm.nih.gov/pubmed/27865876</a>
#
#
#             </tr>
#
#         </tbody>
#         </table>

# %%
results.head()
# Out:
#           pmid                                             author      date  \
# 1510  28182861  Egashira R, Jacob J, Kokosi MA, Brun AL, Rice ...  2017 Jul
# 4560  27471881    Mlika M, Kria N, Braham E, Chebbi C, El Mezni F      2017
# 3244  28130491  Podolanczuk AJ, Raghu G, Tsai MY, Kawut SM, Pe...  2017 May
# 86    27708114  Kreuter M, Bonella F, Maher TM, Costabel U, Sp...  2017 Feb
# 99    28115263  Moradi P, Keyvani H, Javad Mousavi SA, Karbala...  2017 Mar
#
#                                                   title  \
# 1510  Diffuse Pulmonary Ossification in Fibrosing In...
# 4560  The diagnostic importance of the bronchoalveol...
# 3244  Cholesterol, lipoproteins and subclinical inte...
# 86    Effect of statins on disease-related outcomes ...
# 99    Investigation of viral infection in idiopathic...
#
#                                        journal  \
# 1510                                 Radiology
# 4560  Journal of immunoassay & immunochemistry
# 3244                                    Thorax
# 86                                      Thorax
# 99                      Microbial pathogenesis
#
#                                               key_words  \
# 1510  Aged, Biopsy, Female, Humans, Idiopathic Pulmo...
# 4560  Adolescent, Adult, Aged, Bronchoalveolar Lavag...
# 3244  Aged, Aged, 80 and over, Biomarkers/blood, Cho...
# 86    Adult, Aged, Aged, 80 and over, Disease Progre...
# 99    Adenoviruses, Human/*isolation & purification,...
#
#                                                pub_type  \
# 1510                                    Journal Article
# 4560                                    Journal Article
# 3244                          Letter, Multicenter Study
# 86    Clinical Trial, Phase III, Journal Article, Ra...
# 99                                      Journal Article
#
#                                                abstract  target  testresult  \
# 1510  Purpose To investigate the prevalence of diffu...       0           1
# 4560  Multidisciplinary concertation is mandatory in...       0           1
# 3244  We investigated associations of plasma lipopro...       0           1
# 86    BACKGROUND: Data are conflicting regarding the...       0           1
# 99    AIM OF THE STUDY: Idiopathic pulmonary fibrosi...       0           1
#
#       testprob                                          link
# 1510  1.000000  https://www.ncbi.nlm.nih.gov/pubmed/28182861
# 4560  0.999997  https://www.ncbi.nlm.nih.gov/pubmed/27471881
# 3244  0.999995  https://www.ncbi.nlm.nih.gov/pubmed/28130491
# 86    0.829780  https://www.ncbi.nlm.nih.gov/pubmed/27708114
# 99    0.809333  https://www.ncbi.nlm.nih.gov/pubmed/28115263
