# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
G = nx.read_gexf('graph.gexf')

# %%
nx.draw(G)

# %%
citing = np.load('citing.npy').item()

# %%
#pos=nx.spring_layout(G)

pos = graphviz_layout(G, prog='dot')

nx.draw_networkx_nodes(G,pos,
                       nodelist=citing.keys(),
                       node_color='r',
                       node_size=200,
                       alpha=0.8)

nx.draw_networkx_nodes(G,pos,
                       nodelist=[item for sublist in citing.values() for item in sublist],
                       node_color='b',
                       node_size=50,
                       alpha=0.8)

labels={}
labels[0]=r'$a$'

nx.draw_networkx_labels(G,pos,labels,font_size=16)

nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-4201f4d49ebd> in <module>()
#      18 labels[0]=r'$a$'
#      19
# ---> 20 nx.draw_networkx_labels(G,pos,labels,font_size=16)
#      21
#      22 nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)
#
# /home/drcjar/.virtualenvs/litsearch/local/lib/python2.7/site-packages/networkx/drawing/nx_pylab.pyc in draw_networkx_labels(G, pos, labels, font_size, font_color, font_family, font_weight, alpha, bbox, ax, **kwds)
#     721     text_items = {}  # there is no text collection so we'll fake one
#     722     for n, label in labels.items():
# --> 723         (x, y) = pos[n]
#     724         if not cb.is_string_like(label):
#     725             label = str(label)  # this will cause "1" and 1 to be labeled the same
#
# KeyError: 0

# %%
from networkx.drawing.nx_agraph import graphviz_layout

pos = graphviz_layout(G)

nx.draw(G, pos, prog='dot')
